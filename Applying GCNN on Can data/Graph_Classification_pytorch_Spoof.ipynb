# %%
# !unzip /content/RPM_dataset.zip
# Out:
# Archive:  /content/RPM_dataset.zip
#   inflating: RPM_dataset.csv

# %%
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install -q torch-geometric

# %%
import torch
from torch_geometric.data import Data

edge_index = torch.tensor([[0, 1, 3, 4],
                           [1, 0, 1, 1]], dtype=torch.long)
x = torch.tensor([[-1], [0], [1]], dtype=torch.float)

data = Data(x=x, edge_index=edge_index.t().contiguous())

print(data['x'])
# Out:
# tensor([[-1.],
#         [ 0.],
#         [ 1.]])

# %%
import numpy as np

attackFreeArray = []
file = open('/content/RPM_dataset.csv', 'r')
attackList = []
counter = 0
graphList = []
ultimateGraphList = [] 
uttimateDetectionList = []
graphCounter = 0

noOfMessages = 200
for line in file:
  Xpartition = line.split()[0].split(',')
  attackList.append(Xpartition[len(Xpartition)-1])

  
  node = Xpartition[1]

  graphList.append(node)
  if len(graphList) == noOfMessages: #No of messages
    ultimateGraphList.append(graphList)
    uttimateDetectionList.append(attackList)

  
    graphCounter+=1    
    graphList = []
    attackList = []
  

ugl = ultimateGraphList
udl = uttimateDetectionList



print(len(graphList))
print(len(ugl))
print(ugl[3])
print(len(udl))
print(udl[0])
# Out:
# 102
# 23108
# ['0002', '0153', '0130', '0131', '0140', '043f', '0370', '0440', '0350', '0316', '018f', '0260', '02a0', '0329', '04f0', '0545', '02c0', '0430', '04b1', '01f1', '0153', '0002', '00a0', '00a1', '0130', '0131', '0140', '0370', '043f', '0440', '0350', '0316', '018f', '0260', '02a0', '0329', '0545', '02c0', '0002', '0153', '0130', '0131', '0140', '043f', '0370', '0440', '0350', '04f0', '0316', '018f', '0260', '02a0', '0329', '0545', '02c0', '0430', '04b1', '01f1', '0153', '0002', '0130', '0131', '0140', '0370', '043f', '0440', '0350', '0316', '018f', '0260', '02a0', '0329', '0545', '02c0', '0002', '0153', '0130', '0131', '0140', '043f', '0370', '0440', '0350', '0316', '018f', '0260', '02a0', '0329', '04f0', '0545', '05f0', '02c0', '0430', '04b1', '01f1', '0153', '0002', '0130', '0131', '0140', '0370', '043f', '0440', '0350', '0316', '018f', '0260', '02a0', '0329', '0545', '02c0', '0002', '0153', '0130', '0131', '0140', '043f', '0370', '0440', '0350', '04f0', '018f', '0260', '02a0', '0316', '0329', '0545', '02c0', '0430', '04b1', '01f1', '0153', '0002', '0130', '0131', '0140', '0370', '043f', '0440', '0350', '0316', '018f', '0260', '02a0', '0329', '0545', '02c0', '0002', '0153', '0130', '0131', '0140', '043f', '0370', '0440', '0350', '0316', '018f', '0260', '02a0', '0329', '04f0', '0545', '02c0', '0430', '04b1', '01f1', '0153', '0002', '0130', '0131', '0140', '0370', '043f', '0440', '0350', '0690', '0316', '018f', '0260', '02a0', '0329', '0545', '05f0', '02c0', '0002', '0153', '0130', '0131', '0140', '043f', '0370', '0440', '0350', '0316', '018f', '0260', '02a0', '0329', '04f0']
# 23108
# ['R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R']

# %%
#Making graph from the 200 sequential of id and store them in a file as Graph adjacent list
from collections import defaultdict
import networkx as nx
import matplotlib.pyplot as plt
import random
import torch
from scipy.sparse import csr_matrix
from torch_geometric.data import Data, DataLoader
gAttackfree=nx.DiGraph()
gAttacked = nx.DiGraph()

lenugl = len(ugl)

counter = 0
gAttackfreeCounter = 0
gAttackedCounter = 0



allLabelList = []
nodeFeatureList = []
uvList = []
DataList = []
for i in range(0,lenugl):
  uList = []
  vList = []
  attackFree = 0
  fList = []
  all_unique_nodes = list(set(ugl[i]))
  ln = len(all_unique_nodes)
  array = np.zeros((ln,ln))
  for j in range (0, len(ugl[i])-1):
     u = all_unique_nodes.index(ugl[i][j])
     v = all_unique_nodes.index(ugl[i][j+1])
     uList.append(u)
     vList.append(v)
     array[u][v] = array[u][v]+1
  uvList.append([uList,vList])
  edge_index =  torch.LongTensor([uList,vList])
  
  for k in range(len(array)):
    indeg = 0
    outdeg = 0
    for l in range(len(array[k])):
      outdeg = outdeg + array[k][l]
      indeg = indeg + array[l][k]
    fList.append([indeg,outdeg])
  
  nodeFeatureList.append(fList)
  x = torch.FloatTensor(fList)


  for j in range (0,len(ugl[i])):
    if udl[i][j] == 'T': 
      attackFree = 1
      break

  y = attackFree
  
  allLabelList.append(attackFree)

  DataList.append(Data(x = x,edge_index=edge_index,y=y))




print(uvList[0])
print(allLabelList.count(0))
print(allLabelList.count(1))

print(nodeFeatureList[3])
# Out:
# [[3, 10, 18, 2, 15, 14, 11, 12, 0, 4, 5, 20, 8, 21, 23, 6, 1, 3, 10, 18, 2, 15, 14, 11, 16, 17, 7, 0, 12, 4, 5, 20, 21, 8, 23, 6, 19, 3, 10, 18, 2, 15, 14, 9, 11, 12, 0, 4, 5, 20, 8, 21, 23, 6, 1, 3, 10, 18, 2, 15, 14, 11, 16, 17, 7, 0, 12, 22, 13, 4, 5, 20, 21, 8, 23, 6, 3, 10, 18, 2, 15, 14, 11, 12, 0, 4, 5, 20, 8, 21, 23, 6, 3, 10, 18, 2, 15, 1, 14, 11, 16, 17, 7, 0, 12, 4, 5, 20, 21, 8, 23, 6, 3, 10, 18, 2, 15, 14, 11, 12, 0, 4, 5, 20, 8, 21, 23, 6, 1, 3, 10, 18, 2, 15, 14, 9, 11, 16, 17, 7, 0, 12, 4, 5, 20, 21, 8, 23, 6, 3, 10, 18, 2, 15, 14, 11, 12, 0, 4, 5, 20, 8, 21, 23, 6, 1, 10, 18, 2, 3, 15, 14, 11, 16, 17, 7, 0, 12, 4, 5, 20, 21, 8, 23, 6, 3, 10, 18, 2, 15, 14, 11, 12, 0, 4, 5, 20, 8, 21], [10, 18, 2, 15, 14, 11, 12, 0, 4, 5, 20, 8, 21, 23, 6, 1, 3, 10, 18, 2, 15, 14, 11, 16, 17, 7, 0, 12, 4, 5, 20, 21, 8, 23, 6, 19, 3, 10, 18, 2, 15, 14, 9, 11, 12, 0, 4, 5, 20, 8, 21, 23, 6, 1, 3, 10, 18, 2, 15, 14, 11, 16, 17, 7, 0, 12, 22, 13, 4, 5, 20, 21, 8, 23, 6, 3, 10, 18, 2, 15, 14, 11, 12, 0, 4, 5, 20, 8, 21, 23, 6, 3, 10, 18, 2, 15, 1, 14, 11, 16, 17, 7, 0, 12, 4, 5, 20, 21, 8, 23, 6, 3, 10, 18, 2, 15, 14, 11, 12, 0, 4, 5, 20, 8, 21, 23, 6, 1, 3, 10, 18, 2, 15, 14, 9, 11, 16, 17, 7, 0, 12, 4, 5, 20, 21, 8, 23, 6, 3, 10, 18, 2, 15, 14, 11, 12, 0, 4, 5, 20, 8, 21, 23, 6, 1, 10, 18, 2, 3, 15, 14, 11, 16, 17, 7, 0, 12, 4, 5, 20, 21, 8, 23, 6, 3, 10, 18, 2, 15, 14, 11, 12, 0, 4, 5, 20, 8, 21, 23]]
# 12496
# 10612
# [[11.0, 11.0], [6.0, 5.0], [11.0, 11.0], [11.0, 11.0], [11.0, 11.0], [11.0, 11.0], [11.0, 11.0], [5.0, 5.0], [11.0, 11.0], [2.0, 2.0], [11.0, 11.0], [10.0, 11.0], [10.0, 10.0], [1.0, 1.0], [10.0, 10.0], [11.0, 11.0], [5.0, 5.0], [5.0, 5.0], [11.0, 11.0], [1.0, 1.0], [11.0, 11.0], [11.0, 11.0], [1.0, 1.0], [11.0, 11.0]]

# %%
import random 


torch.manual_seed(12345)
random.shuffle(DataList)

dataset = DataList


train_size = int(lenugl*.70)

#print(int(train_size))


train_dataset = dataset[:train_size]
test_dataset = dataset[train_size:lenugl]

print(f'Number of training graphs: {len(train_dataset)}')
print(f'Number of test graphs: {len(test_dataset)}')
# Out:
# Number of training graphs: 16175
# Number of test graphs: 6933

# %%
from torch_geometric.data import DataLoader

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset,batch_size=128, shuffle=False)

for step, data in enumerate(train_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()
# Out:
# Step 1:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1522], edge_index=[2, 12736], x=[1522, 2], y=[64])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1510], edge_index=[2, 12736], x=[1510, 2], y=[64])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1519], edge_index=[2, 12736], x=[1519, 2], y=[64])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1526], edge_index=[2, 12736], x=[1526, 2], y=[64])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1524], edge_index=[2, 12736], x=[1524, 2], y=[64])
#
# Step 6:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1532], edge_index=[2, 12736], x=[1532, 2], y=[64])
#
# Step 7:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1510], edge_index=[2, 12736], x=[1510, 2], y=[64])
#
# Step 8:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1526], edge_index=[2, 12736], x=[1526, 2], y=[64])
#
# Step 9:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1527], edge_index=[2, 12736], x=[1527, 2], y=[64])
#
# Step 10:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1507], edge_index=[2, 12736], x=[1507, 2], y=[64])
#
# Step 11:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1520], edge_index=[2, 12736], x=[1520, 2], y=[64])
#
# Step 12:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1507], edge_index=[2, 12736], x=[1507, 2], y=[64])
#
# Step 13:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1511], edge_index=[2, 12736], x=[1511, 2], y=[64])
#
# Step 14:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1510], edge_index=[2, 12736], x=[1510, 2], y=[64])
#
# Step 15:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1513], edge_index=[2, 12736], x=[1513, 2], y=[64])
#
# Step 16:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1526], edge_index=[2, 12736], x=[1526, 2], y=[64])
#
# Step 17:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1520], edge_index=[2, 12736], x=[1520, 2], y=[64])
#
# Step 18:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1525], edge_index=[2, 12736], x=[1525, 2], y=[64])
#
# Step 19:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1516], edge_index=[2, 12736], x=[1516, 2], y=[64])
#
# Step 20:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1518], edge_index=[2, 12736], x=[1518, 2], y=[64])
#
# Step 21:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1524], edge_index=[2, 12736], x=[1524, 2], y=[64])
#
# Step 22:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1532], edge_index=[2, 12736], x=[1532, 2], y=[64])
#
# Step 23:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1529], edge_index=[2, 12736], x=[1529, 2], y=[64])
#
# Step 24:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1526], edge_index=[2, 12736], x=[1526, 2], y=[64])
#
# Step 25:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1514], edge_index=[2, 12736], x=[1514, 2], y=[64])
#
# Step 26:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1519], edge_index=[2, 12736], x=[1519, 2], y=[64])
#
# Step 27:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1496], edge_index=[2, 12736], x=[1496, 2], y=[64])
#
# Step 28:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1514], edge_index=[2, 12736], x=[1514, 2], y=[64])
#
# Step 29:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1512], edge_index=[2, 12736], x=[1512, 2], y=[64])
#
# Step 30:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1513], edge_index=[2, 12736], x=[1513, 2], y=[64])
#
# Step 31:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1531], edge_index=[2, 12736], x=[1531, 2], y=[64])
#
# Step 32:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1500], edge_index=[2, 12736], x=[1500, 2], y=[64])
#
# Step 33:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1509], edge_index=[2, 12736], x=[1509, 2], y=[64])
#
# Step 34:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1508], edge_index=[2, 12736], x=[1508, 2], y=[64])
#
# Step 35:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1515], edge_index=[2, 12736], x=[1515, 2], y=[64])
#
# Step 36:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1508], edge_index=[2, 12736], x=[1508, 2], y=[64])
#
# Step 37:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1510], edge_index=[2, 12736], x=[1510, 2], y=[64])
#
# Step 38:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1510], edge_index=[2, 12736], x=[1510, 2], y=[64])
#
# Step 39:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1514], edge_index=[2, 12736], x=[1514, 2], y=[64])
#
# Step 40:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1528], edge_index=[2, 12736], x=[1528, 2], y=[64])
#
# Step 41:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1514], edge_index=[2, 12736], x=[1514, 2], y=[64])
#
# Step 42:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1528], edge_index=[2, 12736], x=[1528, 2], y=[64])
#
# Step 43:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1530], edge_index=[2, 12736], x=[1530, 2], y=[64])
#
# Step 44:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1513], edge_index=[2, 12736], x=[1513, 2], y=[64])
#
# Step 45:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1517], edge_index=[2, 12736], x=[1517, 2], y=[64])
#
# Step 46:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1524], edge_index=[2, 12736], x=[1524, 2], y=[64])
#
# Step 47:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1514], edge_index=[2, 12736], x=[1514, 2], y=[64])
#
# Step 48:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1511], edge_index=[2, 12736], x=[1511, 2], y=[64])
#
# Step 49:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1514], edge_index=[2, 12736], x=[1514, 2], y=[64])
#
# Step 50:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1520], edge_index=[2, 12736], x=[1520, 2], y=[64])
#
# Step 51:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1507], edge_index=[2, 12736], x=[1507, 2], y=[64])
#
# Step 52:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1513], edge_index=[2, 12736], x=[1513, 2], y=[64])
#
# Step 53:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1520], edge_index=[2, 12736], x=[1520, 2], y=[64])
#
# Step 54:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1513], edge_index=[2, 12736], x=[1513, 2], y=[64])
#
# Step 55:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1523], edge_index=[2, 12736], x=[1523, 2], y=[64])
#
# Step 56:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1518], edge_index=[2, 12736], x=[1518, 2], y=[64])
#
# Step 57:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1523], edge_index=[2, 12736], x=[1523, 2], y=[64])
#
# Step 58:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1523], edge_index=[2, 12736], x=[1523, 2], y=[64])
#
# Step 59:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1513], edge_index=[2, 12736], x=[1513, 2], y=[64])
#
# Step 60:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1524], edge_index=[2, 12736], x=[1524, 2], y=[64])
#
# Step 61:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1518], edge_index=[2, 12736], x=[1518, 2], y=[64])
#
# Step 62:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1505], edge_index=[2, 12736], x=[1505, 2], y=[64])
#
# Step 63:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1509], edge_index=[2, 12736], x=[1509, 2], y=[64])
#
# Step 64:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1519], edge_index=[2, 12736], x=[1519, 2], y=[64])
#
# Step 65:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1505], edge_index=[2, 12736], x=[1505, 2], y=[64])
#
# Step 66:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1533], edge_index=[2, 12736], x=[1533, 2], y=[64])
#
# Step 67:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1513], edge_index=[2, 12736], x=[1513, 2], y=[64])
#
# Step 68:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1527], edge_index=[2, 12736], x=[1527, 2], y=[64])
#
# Step 69:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1518], edge_index=[2, 12736], x=[1518, 2], y=[64])
#
# Step 70:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1511], edge_index=[2, 12736], x=[1511, 2], y=[64])
#
# Step 71:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1522], edge_index=[2, 12736], x=[1522, 2], y=[64])
#
# Step 72:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1501], edge_index=[2, 12736], x=[1501, 2], y=[64])
#
# Step 73:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1508], edge_index=[2, 12736], x=[1508, 2], y=[64])
#
# Step 74:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1510], edge_index=[2, 12736], x=[1510, 2], y=[64])
#
# Step 75:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1519], edge_index=[2, 12736], x=[1519, 2], y=[64])
#
# Step 76:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1517], edge_index=[2, 12736], x=[1517, 2], y=[64])
#
# Step 77:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1513], edge_index=[2, 12736], x=[1513, 2], y=[64])
#
# Step 78:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1519], edge_index=[2, 12736], x=[1519, 2], y=[64])
#
# Step 79:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1526], edge_index=[2, 12736], x=[1526, 2], y=[64])
#
# Step 80:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1516], edge_index=[2, 12736], x=[1516, 2], y=[64])
#
# Step 81:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1505], edge_index=[2, 12736], x=[1505, 2], y=[64])
#
# Step 82:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1515], edge_index=[2, 12736], x=[1515, 2], y=[64])
#
# Step 83:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1524], edge_index=[2, 12736], x=[1524, 2], y=[64])
#
# Step 84:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1520], edge_index=[2, 12736], x=[1520, 2], y=[64])
#
# Step 85:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1512], edge_index=[2, 12736], x=[1512, 2], y=[64])
#
# Step 86:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1523], edge_index=[2, 12736], x=[1523, 2], y=[64])
#
# Step 87:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1523], edge_index=[2, 12736], x=[1523, 2], y=[64])
#
# Step 88:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1497], edge_index=[2, 12736], x=[1497, 2], y=[64])
#
# Step 89:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1508], edge_index=[2, 12736], x=[1508, 2], y=[64])
#
# Step 90:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1538], edge_index=[2, 12736], x=[1538, 2], y=[64])
#
# Step 91:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1534], edge_index=[2, 12736], x=[1534, 2], y=[64])
#
# Step 92:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1516], edge_index=[2, 12736], x=[1516, 2], y=[64])
#
# Step 93:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1518], edge_index=[2, 12736], x=[1518, 2], y=[64])
#
# Step 94:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1511], edge_index=[2, 12736], x=[1511, 2], y=[64])
#
# Step 95:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1521], edge_index=[2, 12736], x=[1521, 2], y=[64])
#
# Step 96:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1509], edge_index=[2, 12736], x=[1509, 2], y=[64])
#
# Step 97:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1538], edge_index=[2, 12736], x=[1538, 2], y=[64])
#
# Step 98:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1527], edge_index=[2, 12736], x=[1527, 2], y=[64])
#
# Step 99:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1497], edge_index=[2, 12736], x=[1497, 2], y=[64])
#
# Step 100:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1518], edge_index=[2, 12736], x=[1518, 2], y=[64])
#
# Step 101:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1504], edge_index=[2, 12736], x=[1504, 2], y=[64])
#
# Step 102:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1508], edge_index=[2, 12736], x=[1508, 2], y=[64])
#
# Step 103:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1519], edge_index=[2, 12736], x=[1519, 2], y=[64])
#
# Step 104:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1513], edge_index=[2, 12736], x=[1513, 2], y=[64])
#
# Step 105:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1521], edge_index=[2, 12736], x=[1521, 2], y=[64])
#
# Step 106:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1504], edge_index=[2, 12736], x=[1504, 2], y=[64])
#
# Step 107:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1510], edge_index=[2, 12736], x=[1510, 2], y=[64])
#
# Step 108:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1534], edge_index=[2, 12736], x=[1534, 2], y=[64])
#
# Step 109:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1509], edge_index=[2, 12736], x=[1509, 2], y=[64])
#
# Step 110:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1526], edge_index=[2, 12736], x=[1526, 2], y=[64])
#
# Step 111:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1532], edge_index=[2, 12736], x=[1532, 2], y=[64])
#
# Step 112:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1514], edge_index=[2, 12736], x=[1514, 2], y=[64])
#
# Step 113:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1523], edge_index=[2, 12736], x=[1523, 2], y=[64])
#
# Step 114:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1516], edge_index=[2, 12736], x=[1516, 2], y=[64])
#
# Step 115:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1531], edge_index=[2, 12736], x=[1531, 2], y=[64])
#
# Step 116:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1529], edge_index=[2, 12736], x=[1529, 2], y=[64])
#
# Step 117:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1519], edge_index=[2, 12736], x=[1519, 2], y=[64])
#
# Step 118:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1529], edge_index=[2, 12736], x=[1529, 2], y=[64])
#
# Step 119:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1518], edge_index=[2, 12736], x=[1518, 2], y=[64])
#
# Step 120:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1522], edge_index=[2, 12736], x=[1522, 2], y=[64])
#
# Step 121:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1509], edge_index=[2, 12736], x=[1509, 2], y=[64])
#
# Step 122:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1517], edge_index=[2, 12736], x=[1517, 2], y=[64])
#
# Step 123:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1527], edge_index=[2, 12736], x=[1527, 2], y=[64])
#
# Step 124:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1524], edge_index=[2, 12736], x=[1524, 2], y=[64])
#
# Step 125:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1523], edge_index=[2, 12736], x=[1523, 2], y=[64])
#
# Step 126:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1526], edge_index=[2, 12736], x=[1526, 2], y=[64])
#
# Step 127:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1516], edge_index=[2, 12736], x=[1516, 2], y=[64])
#
# Step 128:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1512], edge_index=[2, 12736], x=[1512, 2], y=[64])
#
# Step 129:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1524], edge_index=[2, 12736], x=[1524, 2], y=[64])
#
# Step 130:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1514], edge_index=[2, 12736], x=[1514, 2], y=[64])
#
# Step 131:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1533], edge_index=[2, 12736], x=[1533, 2], y=[64])
#
# Step 132:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1507], edge_index=[2, 12736], x=[1507, 2], y=[64])
#
# Step 133:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1520], edge_index=[2, 12736], x=[1520, 2], y=[64])
#
# Step 134:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1514], edge_index=[2, 12736], x=[1514, 2], y=[64])
#
# Step 135:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1524], edge_index=[2, 12736], x=[1524, 2], y=[64])
#
# Step 136:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1525], edge_index=[2, 12736], x=[1525, 2], y=[64])
#
# Step 137:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1524], edge_index=[2, 12736], x=[1524, 2], y=[64])
#
# Step 138:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1522], edge_index=[2, 12736], x=[1522, 2], y=[64])
#
# Step 139:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1536], edge_index=[2, 12736], x=[1536, 2], y=[64])
#
# Step 140:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1516], edge_index=[2, 12736], x=[1516, 2], y=[64])
#
# Step 141:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1507], edge_index=[2, 12736], x=[1507, 2], y=[64])
#
# Step 142:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1523], edge_index=[2, 12736], x=[1523, 2], y=[64])
#
# Step 143:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1527], edge_index=[2, 12736], x=[1527, 2], y=[64])
#
# Step 144:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1520], edge_index=[2, 12736], x=[1520, 2], y=[64])
#
# Step 145:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1518], edge_index=[2, 12736], x=[1518, 2], y=[64])
#
# Step 146:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1529], edge_index=[2, 12736], x=[1529, 2], y=[64])
#
# Step 147:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1509], edge_index=[2, 12736], x=[1509, 2], y=[64])
#
# Step 148:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1520], edge_index=[2, 12736], x=[1520, 2], y=[64])
#
# Step 149:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1532], edge_index=[2, 12736], x=[1532, 2], y=[64])
#
# Step 150:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1524], edge_index=[2, 12736], x=[1524, 2], y=[64])
#
# Step 151:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1524], edge_index=[2, 12736], x=[1524, 2], y=[64])
#
# Step 152:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1517], edge_index=[2, 12736], x=[1517, 2], y=[64])
#
# Step 153:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1537], edge_index=[2, 12736], x=[1537, 2], y=[64])
#
# Step 154:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1521], edge_index=[2, 12736], x=[1521, 2], y=[64])
#
# Step 155:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1508], edge_index=[2, 12736], x=[1508, 2], y=[64])
#
# Step 156:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1527], edge_index=[2, 12736], x=[1527, 2], y=[64])
#
# Step 157:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1527], edge_index=[2, 12736], x=[1527, 2], y=[64])
#
# Step 158:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1523], edge_index=[2, 12736], x=[1523, 2], y=[64])
#
# Step 159:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1518], edge_index=[2, 12736], x=[1518, 2], y=[64])
#
# Step 160:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1527], edge_index=[2, 12736], x=[1527, 2], y=[64])
#
# Step 161:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1512], edge_index=[2, 12736], x=[1512, 2], y=[64])
#
# Step 162:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1529], edge_index=[2, 12736], x=[1529, 2], y=[64])
#
# Step 163:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1516], edge_index=[2, 12736], x=[1516, 2], y=[64])
#
# Step 164:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1531], edge_index=[2, 12736], x=[1531, 2], y=[64])
#
# Step 165:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1514], edge_index=[2, 12736], x=[1514, 2], y=[64])
#
# Step 166:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1512], edge_index=[2, 12736], x=[1512, 2], y=[64])
#
# Step 167:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1525], edge_index=[2, 12736], x=[1525, 2], y=[64])
#
# Step 168:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1516], edge_index=[2, 12736], x=[1516, 2], y=[64])
#
# Step 169:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1522], edge_index=[2, 12736], x=[1522, 2], y=[64])
#
# Step 170:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1514], edge_index=[2, 12736], x=[1514, 2], y=[64])
#
# Step 171:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1531], edge_index=[2, 12736], x=[1531, 2], y=[64])
#
# Step 172:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1518], edge_index=[2, 12736], x=[1518, 2], y=[64])
#
# Step 173:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1518], edge_index=[2, 12736], x=[1518, 2], y=[64])
#
# Step 174:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1505], edge_index=[2, 12736], x=[1505, 2], y=[64])
#
# Step 175:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1530], edge_index=[2, 12736], x=[1530, 2], y=[64])
#
# Step 176:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1517], edge_index=[2, 12736], x=[1517, 2], y=[64])
#
# Step 177:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1513], edge_index=[2, 12736], x=[1513, 2], y=[64])
#
# Step 178:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1510], edge_index=[2, 12736], x=[1510, 2], y=[64])
#
# Step 179:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1534], edge_index=[2, 12736], x=[1534, 2], y=[64])
#
# Step 180:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1528], edge_index=[2, 12736], x=[1528, 2], y=[64])
#
# Step 181:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1521], edge_index=[2, 12736], x=[1521, 2], y=[64])
#
# Step 182:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1520], edge_index=[2, 12736], x=[1520, 2], y=[64])
#
# Step 183:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1520], edge_index=[2, 12736], x=[1520, 2], y=[64])
#
# Step 184:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1506], edge_index=[2, 12736], x=[1506, 2], y=[64])
#
# Step 185:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1510], edge_index=[2, 12736], x=[1510, 2], y=[64])
#
# Step 186:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1520], edge_index=[2, 12736], x=[1520, 2], y=[64])
#
# Step 187:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1528], edge_index=[2, 12736], x=[1528, 2], y=[64])
#
# Step 188:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1535], edge_index=[2, 12736], x=[1535, 2], y=[64])
#
# Step 189:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1518], edge_index=[2, 12736], x=[1518, 2], y=[64])
#
# Step 190:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1515], edge_index=[2, 12736], x=[1515, 2], y=[64])
#
# Step 191:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1533], edge_index=[2, 12736], x=[1533, 2], y=[64])
#
# Step 192:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1518], edge_index=[2, 12736], x=[1518, 2], y=[64])
#
# Step 193:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1521], edge_index=[2, 12736], x=[1521, 2], y=[64])
#
# Step 194:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1526], edge_index=[2, 12736], x=[1526, 2], y=[64])
#
# Step 195:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1516], edge_index=[2, 12736], x=[1516, 2], y=[64])
#
# Step 196:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1527], edge_index=[2, 12736], x=[1527, 2], y=[64])
#
# Step 197:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1520], edge_index=[2, 12736], x=[1520, 2], y=[64])
#
# Step 198:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1528], edge_index=[2, 12736], x=[1528, 2], y=[64])
#
# Step 199:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1522], edge_index=[2, 12736], x=[1522, 2], y=[64])
#
# Step 200:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1519], edge_index=[2, 12736], x=[1519, 2], y=[64])
#
# Step 201:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1523], edge_index=[2, 12736], x=[1523, 2], y=[64])
#
# Step 202:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1522], edge_index=[2, 12736], x=[1522, 2], y=[64])
#
# Step 203:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1518], edge_index=[2, 12736], x=[1518, 2], y=[64])
#
# Step 204:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1523], edge_index=[2, 12736], x=[1523, 2], y=[64])
#
# Step 205:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1529], edge_index=[2, 12736], x=[1529, 2], y=[64])
#
# Step 206:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1508], edge_index=[2, 12736], x=[1508, 2], y=[64])
#
# Step 207:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1530], edge_index=[2, 12736], x=[1530, 2], y=[64])
#
# Step 208:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1515], edge_index=[2, 12736], x=[1515, 2], y=[64])
#
# Step 209:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1516], edge_index=[2, 12736], x=[1516, 2], y=[64])
#
# Step 210:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1513], edge_index=[2, 12736], x=[1513, 2], y=[64])
#
# Step 211:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1528], edge_index=[2, 12736], x=[1528, 2], y=[64])
#
# Step 212:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1513], edge_index=[2, 12736], x=[1513, 2], y=[64])
#
# Step 213:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1522], edge_index=[2, 12736], x=[1522, 2], y=[64])
#
# Step 214:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1512], edge_index=[2, 12736], x=[1512, 2], y=[64])
#
# Step 215:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1519], edge_index=[2, 12736], x=[1519, 2], y=[64])
#
# Step 216:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1508], edge_index=[2, 12736], x=[1508, 2], y=[64])
#
# Step 217:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1529], edge_index=[2, 12736], x=[1529, 2], y=[64])
#
# Step 218:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1519], edge_index=[2, 12736], x=[1519, 2], y=[64])
#
# Step 219:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1513], edge_index=[2, 12736], x=[1513, 2], y=[64])
#
# Step 220:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1530], edge_index=[2, 12736], x=[1530, 2], y=[64])
#
# Step 221:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1515], edge_index=[2, 12736], x=[1515, 2], y=[64])
#
# Step 222:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1537], edge_index=[2, 12736], x=[1537, 2], y=[64])
#
# Step 223:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1510], edge_index=[2, 12736], x=[1510, 2], y=[64])
#
# Step 224:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1512], edge_index=[2, 12736], x=[1512, 2], y=[64])
#
# Step 225:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1527], edge_index=[2, 12736], x=[1527, 2], y=[64])
#
# Step 226:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1521], edge_index=[2, 12736], x=[1521, 2], y=[64])
#
# Step 227:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1536], edge_index=[2, 12736], x=[1536, 2], y=[64])
#
# Step 228:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1527], edge_index=[2, 12736], x=[1527, 2], y=[64])
#
# Step 229:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1507], edge_index=[2, 12736], x=[1507, 2], y=[64])
#
# Step 230:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1523], edge_index=[2, 12736], x=[1523, 2], y=[64])
#
# Step 231:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1514], edge_index=[2, 12736], x=[1514, 2], y=[64])
#
# Step 232:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1510], edge_index=[2, 12736], x=[1510, 2], y=[64])
#
# Step 233:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1502], edge_index=[2, 12736], x=[1502, 2], y=[64])
#
# Step 234:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1524], edge_index=[2, 12736], x=[1524, 2], y=[64])
#
# Step 235:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1533], edge_index=[2, 12736], x=[1533, 2], y=[64])
#
# Step 236:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1528], edge_index=[2, 12736], x=[1528, 2], y=[64])
#
# Step 237:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1516], edge_index=[2, 12736], x=[1516, 2], y=[64])
#
# Step 238:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1501], edge_index=[2, 12736], x=[1501, 2], y=[64])
#
# Step 239:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1518], edge_index=[2, 12736], x=[1518, 2], y=[64])
#
# Step 240:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1540], edge_index=[2, 12736], x=[1540, 2], y=[64])
#
# Step 241:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1520], edge_index=[2, 12736], x=[1520, 2], y=[64])
#
# Step 242:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1521], edge_index=[2, 12736], x=[1521, 2], y=[64])
#
# Step 243:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1505], edge_index=[2, 12736], x=[1505, 2], y=[64])
#
# Step 244:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1531], edge_index=[2, 12736], x=[1531, 2], y=[64])
#
# Step 245:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1512], edge_index=[2, 12736], x=[1512, 2], y=[64])
#
# Step 246:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1517], edge_index=[2, 12736], x=[1517, 2], y=[64])
#
# Step 247:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1519], edge_index=[2, 12736], x=[1519, 2], y=[64])
#
# Step 248:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1520], edge_index=[2, 12736], x=[1520, 2], y=[64])
#
# Step 249:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1522], edge_index=[2, 12736], x=[1522, 2], y=[64])
#
# Step 250:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1519], edge_index=[2, 12736], x=[1519, 2], y=[64])
#
# Step 251:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1517], edge_index=[2, 12736], x=[1517, 2], y=[64])
#
# Step 252:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[1511], edge_index=[2, 12736], x=[1511, 2], y=[64])
#
# Step 253:
# =======
# Number of graphs in the current batch: 47
# Batch(batch=[1113], edge_index=[2, 9353], x=[1113, 2], y=[47])

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_mean_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GCNConv(2, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, 2)

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        
        return x

model = GCN(hidden_channels=64)
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(2, 64)
#   (conv2): GCNConv(64, 64)
#   (conv3): GCNConv(64, 64)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
from IPython.display import Javascript
from sklearn.metrics import confusion_matrix
import numpy as np

display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

model = GCN(hidden_channels=64)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()
yTrue = []
yPred = []

def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
         out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
         loss = criterion(out, data.y)  # Compute the loss.
         loss.backward()  # Derive gradients.
         optimizer.step()  # Update parameters based on gradients.
         optimizer.zero_grad()  # Clear gradients.

def test(loader):
     model.eval()

     correct = 0
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch)  
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct += int((pred == data.y).sum())  # Check against ground-truth labels.
     return correct / len(loader.dataset)  # Derive ratio of correct predictions.


kkkk = 11
for epoch in range(1, kkkk):
    train()
    train_acc = test(train_loader)
    
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}')
# Out:
# Epoch: 001, Train Acc: 0.9890
# Epoch: 002, Train Acc: 0.9917
# Epoch: 003, Train Acc: 0.9921
# Epoch: 004, Train Acc: 0.9926
# Epoch: 005, Train Acc: 0.9912
# Epoch: 006, Train Acc: 0.9920
# Epoch: 007, Train Acc: 0.9934
# Epoch: 008, Train Acc: 0.9876
# Epoch: 009, Train Acc: 0.9911
# Epoch: 010, Train Acc: 0.9938

# %%
from sklearn.metrics import confusion_matrix

def conf(yTrue,yPred):
  tp,tn,fp,fn = 0,0,0,0
  for i in range(len(yTrue)):
    if yTrue[i] == yPred[i] and yTrue[i] == 1:
      tn= tn+1

    elif yTrue[i] == yPred[i] and yTrue[i] == 0:
      tp = tp+1
    elif yTrue[i] == 0 and yPred[i] == 1:
      fp=fp+1
    else:
      fn=fn+1
  

  return np.array([[tp,fp],[fn,tn]])
    




def test1(loader):
     model.eval()

     correct = 0
     cf = np.array([[0,0],[0,0]])
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch)  
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct +=(data.y).sum()  # Check against ground-truth labels.
         c=conf(np.array(data.y),np.array(pred))
         print(c)

         cf = cf+c
     print(correct)
      

     return cf  # Derive ratio of correct predictions.

print('isafhksfh')
cf = test1(test_loader)  


cf = cf.T
print(cf)
print((cf[0][0]+cf[1][1])/(cf[0][0]+cf[0][1]+cf[1][0]+cf[1][1]))
# Out:
# isafhksfh
# [[69  0]
#  [ 0 59]]
# [[73  0]
#  [ 1 54]]
# [[62  0]
#  [ 2 64]]
# [[71  0]
#  [ 0 57]]
# [[76  0]
#  [ 0 52]]
# [[69  0]
#  [ 1 58]]
# [[57  0]
#  [ 0 71]]
# [[61  0]
#  [ 3 64]]
# [[80  0]
#  [ 0 48]]
# [[62  0]
#  [ 0 66]]
# [[70  0]
#  [ 2 56]]
# [[66  0]
#  [ 2 60]]
# [[81  0]
#  [ 1 46]]
# [[62  0]
#  [ 2 64]]
# [[70  1]
#  [ 0 57]]
# [[67  0]
#  [ 1 60]]
# [[80  0]
#  [ 0 48]]
# [[70  0]
#  [ 0 58]]
# [[77  0]
#  [ 0 51]]
# [[75  0]
#  [ 0 53]]
# [[62  0]
#  [ 1 65]]
# [[71  0]
#  [ 0 57]]
# [[66  0]
#  [ 0 62]]
# [[64  0]
#  [ 0 64]]
# [[71  0]
#  [ 0 57]]
# [[72  0]
#  [ 1 55]]
# [[77  1]
#  [ 1 49]]
# [[71  0]
#  [ 1 56]]
# [[69  0]
#  [ 0 59]]
# [[67  0]
#  [ 1 60]]
# [[69  2]
#  [ 0 57]]
# [[72  0]
#  [ 0 56]]
# [[66  0]
#  [ 1 61]]
# [[68  0]
#  [ 3 57]]
# [[63  0]
#  [ 2 63]]
# [[64  0]
#  [ 0 64]]
# [[65  0]
#  [ 0 63]]
# [[62  0]
#  [ 0 66]]
# [[73  0]
#  [ 0 55]]
# [[64  1]
#  [ 0 63]]
# [[72  0]
#  [ 1 55]]
# [[66  0]
#  [ 0 62]]
# [[65  0]
#  [ 0 63]]
# [[70  0]
#  [ 0 58]]
# [[64  1]
#  [ 3 60]]
# [[70  0]
#  [ 1 57]]
# [[73  0]
#  [ 1 54]]
# [[79  0]
#  [ 1 48]]
# [[67  1]
#  [ 0 60]]
# [[63  0]
#  [ 0 65]]
# [[75  1]
#  [ 1 51]]
# [[74  0]
#  [ 1 53]]
# [[75  0]
#  [ 2 51]]
# [[58  0]
#  [ 1 69]]
# [[10  0]
#  [ 0 11]]
# tensor(3190)
# [[3735   38]
#  [   8 3152]]
# 0.9933650656281552

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np



cm = cf


cm_matrix = pd.DataFrame(data=cm, columns=["Attack free","Spoofing attacks"], 
                                 index=["Attack free","Spoofing attacks"])
sns.set(font_scale=2.0)
sns.heatmap(cm_matrix, annot=True, fmt= 'g', cmap='YlGnBu')
plt.rcParams['font.size'] = 3
plt.rcParams['figure.figsize'] = (3, 3)  
# plt.title("Confusion Matrix for All attack")
plt.xlabel("Actual label")
plt.ylabel("Predicted label")
plt.yticks(rotation = 45)
plt.xticks(rotation = 45, ha = 'right')
 
plt.savefig('confusion_spoof.pdf', bbox_inches = "tight")
# plt.savefig('confusion_spoof.svg', bbox_inches = "tight")
# plt.savefig('confusion_spoof.png', bbox_inches = "tight")

# %%
# cm = [[1612 ,  10],
#  [   5  ,793]]


tp = cm[0][0]
tn = cm[1][1]
fp = cm[0][1]
fn = cm[1][0]

re = tp/(tp+fn)
pr = tp/(tp+fp)
f1 = 2*pr*re/(pr+re)
fpr = fp / (fp+tn)
print("pr.........."+str(pr))
print("re----"+str(re))

print("f1===="+str(f1))
print("fpr====="+ str(fpr))
print((tp+tn)/(tp+tn+fp+fn))
# Out:
# pr..........0.98989898989899
# re----0.9932432432432432
# f1====0.9915682967959528
# fpr=====0.009708737864077669
# 0.9917355371900827

# %%
71002
170939
0.991287131986724
[[170760   1929]
 [   179  69073]]
 5

35791
85180
0.9906010531449686
[[84065    22]
 [ 1115 35769]]
 10


3659
8438
0.9962800694387038
[[8424   31]
 [  14 3628]]
100


1832
4217
0.993387336749876
[[4197   20]
 [  20 1812]]

803
1617
0.993801652892562
[[1612   10]
 [   5  793]]
 500



 464
746
0.9917355371900827
[[743   7]
 [  3 457]]
 1000



 309
296
0.9917355371900827
[[294   3]
 [  2 306]]
 2k

 175
67
1.0
[[ 67   0]
 [  0 175]]
 5k


 88
33
1.0
[[33  0]
 [ 0 88]]
 10k

# %%
cm =[ [[170760 ,  1929],
 [179 , 69073]],

 [[84065   , 22],
 [ 1115, 35769]],

[[8424 ,  31],
 [  14, 3628]],

 [[4197 ,  20],
 [  20 ,1812]],

 [[1612  , 10],
 [   5  ,793]],

[[743 ,  7],
 [  3 ,457]],


 [[ 67 ,  0],
 [  0 ,175]],

 [[33,  0],
 [ 0, 88]]
]

for i in range(len(cm)):

  tp = cm[i][0][0]
  tn = cm[i][1][1]
  fp = cm[i][0][1]
  fn = cm[i][1][0]

  re = tp/(tp+fn)
  pr = tp/(tp+fp)
  f1 = 2*pr*re/(pr+re)
  fpr = fp / (fp+tn)


  mcc = (tp*tn-fp*fn)/((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))**.5

  fdr = fp/(fp+tp)

  # print("pr.........."+str(pr))
  # print("re----"+str(re))

  # print("f1===="+str(f1))
  # print("fpr====="+ str(fpr))
  print("mcccccc--------->" +str(mcc))
  #print("fdr======="+str(fdr))
  # print((tp+tn)/(tp+tn+fp+fn))
# Out:
# mcccccc--------->0.9789880325873227
# mcccccc--------->0.9778659028555149
# mcccccc--------->0.991178167512607
# mcccccc--------->0.9843402613459972
# mcccccc--------->0.9860106010676708
# mcccccc--------->0.9825172905181248
# mcccccc--------->1.0
# mcccccc--------->1.0

# %%
import pandas as pd

square_node_data = pd.DataFrame(
    {"x": [1, 2, 3, 4], "y": [-0.2, 0.3, 0.0, -0.5]}, index=["a", "b", "c", "d"]
)
square_node_data
# Out:
#    x    y
# a  1 -0.2
# b  2  0.3
# c  3  0.0
# d  4 -0.5

# %%
# Out:
#       Nodes  Edges  ...  MaximumPagerank  MininumPagerank
# No.                 ...
# 1        27    112  ...         0.215139         0.011104
# 2        25     75  ...         0.359649         0.018228
# 3        25     88  ...         0.285778         0.015716
# 4        27     97  ...         0.276848         0.014271
# 5        27    137  ...         0.173902         0.013195
# ...     ...    ...  ...              ...              ...
# 1828     26     70  ...         0.077329         0.013768
# 1829     26     73  ...         0.073358         0.011842
# 1830     26     78  ...         0.067820         0.011954
# 1831     26     85  ...         0.071132         0.009662
# 1832     26     76  ...         0.086512         0.008505
#
# [1832 rows x 9 columns]
# StellarGraph: Undirected multigraph
#  Nodes: 1832, Edges: 0
#
#  Node types:
#   default: [1832]
#     Features: float32 vector, length 9
#     Edge types: none
#
#  Edge types:
