# %%
# !unzip /content/mergeAttackwithAttackFree.zip
# !unzip /content/mergeIdwithAttackfree.zip
# Out:
# Archive:  /content/mergeAttackwithAttackFree.zip
#   inflating: mergeAttackwithAttackFree.txt
# Archive:  /content/mergeIdwithAttackfree.zip
#   inflating: mergeIdwithAttackfree.txt

# %%
# Install required packages.
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.10.0+cu113.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.10.0+cu113.html
# !pip install -q git+https://github.com/rusty1s/pytorch_geometric.git
# Out:
#      |████████████████████████████████| 3.5 MB 8.6 MB/s
#   Building wheel for torch-geometric (setup.py) ... done

# %%
import torch
from torch_geometric.data import Data

edge_index = torch.tensor([[0, 1, 3, 4],
                           [1, 0, 1, 1]], dtype=torch.long)
x = torch.tensor([[-1], [0], [1]], dtype=torch.float)

data = Data(x=x, edge_index=edge_index.t().contiguous())

print(data['x'])
# Out:
# tensor([[-1.],
#         [ 0.],
#         [ 1.]])

# %%
import numpy as np


fileId = open('/content/mergeIdwithAttackfree.txt', 'r')
fileA = open('/content/mergeAttackwithAttackFree.txt','r')
detectList = []
counter = 1
graphList = []
ultimateGraphList = [] 
utlimateaDetectionList = []
graphCounter = 0


messageSize = 200

for line in fileId:
  node = line.split()[0]




  graphList.append(node)
  

  if len(graphList) == messageSize: 
    ultimateGraphList.append(graphList)


    
  
   

    graphList = []
   
   

ugl = ultimateGraphList

for line in fileA:
  attackChecking = line.split()[0]


  detectList.append(attackChecking)
  

  if len(detectList) == messageSize: 
    utlimateaDetectionList.append(detectList)


    detectList = []

udl = utlimateaDetectionList


print(len(ugl))
print(len(udl))

print(ugl[0])
print(len(ugl[0]))
print(len(udl[0]))
print(udl[0])
print(udl[3])
# Out:
# 82497
# 82497
# ['04b0', '05a0', '05a0', '02a0', '0260', '0080', '0081', '0165', '018f', '02b0', '0153', '0220', '0316', '0329', '0545', '043f', '0370', '0440', '0164', '04b1', '0316', '018f', '0260', '0080', '0081', '0165', '02a0', '02b0', '0329', '0153', '01f1', '0220', '0382', '0350', '04f2', '0545', '00a0', '00a1', '0370', '043f', '0440', '04f0', '05a2', '04f1', '05a2', '051a', '0690', '04b0', '0316', '018f', '0080', '0081', '0153', '0153', '0165', '0153', '0220', '0260', '02a0', '02b0', '0329', '0545', '043f', '0370', '0440', '0587', '05a0', '04b1', '0164', '0316', '0260', '02a0', '0080', '0081', '0164', '0165', '0153', '018f', '01f1', '0220', '02b0', '02c0', '0329', '0350', '0370', '0120', '0382', '0164', '043f', '0440', '04f2', '0517', '04f0', '0545', '05a2', '04b0', '0316', '0260', '018f', '0080', '0081', '0165', '0153', '01f1', '0220', '01f1', '02a0', '02b0', '0329', '0545', '043f', '0370', '0440', '0510', '04b1', '0164', '05e4', '0165', '02b0', '0080', '0081', '0153', '018f', '01f1', '0220', '0220', '0220', '0260', '02a0', '0316', '0329', '0350', '0370', '0382', '043f', '0440', '04f2', '0545', '04f0', '04b0', '0316', '0260', '018f', '0080', '0081', '0165', '0153', '0220', '02a0', '02b0', '02c0', '02c0', '0329', '0545', '043f', '0370', '0440', '059b', '04b1', '0164', '0316', '0260', '02a0', '0080', '0081', '0165', '0153', '018f', '01f1', '0220', '02b0', '0329', '0350', '0382', '04b0', '04b0', '0370', '043f', '0440', '04f2', '0545', '04f0', '04b0', '0316', '018f', '0080', '0081', '0165', '0153', '0220', '0260', '02a0', '02b0', '0329', '04b1', '04b1', '0545', '043f', '0110', '0370']
# 200
# 200
# ['R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R']
# ['R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R']

# %%
#Making graph from the 200 sequential of id and store them in a file as Graph adjacent list
from collections import defaultdict
import networkx as nx
import matplotlib.pyplot as plt
import random
import torch
from scipy.sparse import csr_matrix
from torch_geometric.data import Data, DataLoader
gAttackfree=nx.DiGraph()
gAttacked = nx.DiGraph()

lenugl = len(ugl)

counter = 0
gAttackfreeCounter = 0
gAttackedCounter = 0



allLabelList = []
nodeFeatureList = []
uvList = []
DataList = []
for i in range(0,lenugl):
  uList = []
  vList = []
  attackFree = 0
  fList = []
  all_unique_nodes = list(set(ugl[i]))
  ln = len(all_unique_nodes)
  array = np.zeros((ln,ln))
  for j in range (0, len(ugl[i])-1):
     u = all_unique_nodes.index(ugl[i][j])
     v = all_unique_nodes.index(ugl[i][j+1])
     uList.append(u)
     vList.append(v)
     array[u][v] = array[u][v]+1
  uvList.append([uList,vList])
  edge_index =  torch.LongTensor([uList,vList])
  
  for k in range(len(array)):
    indeg = 0
    outdeg = 0
    for l in range(len(array[k])):
      outdeg = outdeg + array[k][l]
      indeg = indeg + array[l][k]
    fList.append([indeg,outdeg])
  
  nodeFeatureList.append(fList)
  x = torch.FloatTensor(fList)


  for j in range (0,len(ugl[i])):
    if udl[i][j] == 'T': 
      attackFree = 1
      break

  y = attackFree
  
  allLabelList.append(attackFree)

  DataList.append(Data(x = x,edge_index=edge_index,y=y))




print(uvList[0])
print(allLabelList.count(0))
print(allLabelList.count(1))

print(nodeFeatureList[3])
# Out:
# [[24, 20, 20, 35, 37, 31, 30, 5, 23, 2, 32, 14, 10, 15, 18, 6, 29, 3, 26, 19, 10, 23, 37, 31, 30, 5, 35, 2, 15, 32, 21, 14, 12, 4, 1, 18, 25, 33, 29, 6, 3, 17, 27, 7, 27, 13, 28, 24, 10, 23, 31, 30, 32, 32, 5, 32, 14, 37, 35, 2, 15, 18, 6, 29, 3, 9, 20, 19, 26, 10, 37, 35, 31, 30, 26, 5, 32, 23, 21, 14, 2, 0, 15, 4, 29, 36, 12, 26, 6, 3, 1, 8, 17, 18, 27, 24, 10, 37, 23, 31, 30, 5, 32, 21, 14, 21, 35, 2, 15, 18, 6, 29, 3, 16, 19, 26, 22, 5, 2, 31, 30, 32, 23, 21, 14, 14, 14, 37, 35, 10, 15, 4, 29, 12, 6, 3, 1, 18, 17, 24, 10, 37, 23, 31, 30, 5, 32, 14, 35, 2, 0, 0, 15, 18, 6, 29, 3, 34, 19, 26, 10, 37, 35, 31, 30, 5, 32, 23, 21, 14, 2, 15, 4, 12, 24, 24, 29, 6, 3, 1, 18, 17, 24, 10, 23, 31, 30, 5, 32, 14, 37, 35, 2, 15, 19, 19, 18, 6, 11], [20, 20, 35, 37, 31, 30, 5, 23, 2, 32, 14, 10, 15, 18, 6, 29, 3, 26, 19, 10, 23, 37, 31, 30, 5, 35, 2, 15, 32, 21, 14, 12, 4, 1, 18, 25, 33, 29, 6, 3, 17, 27, 7, 27, 13, 28, 24, 10, 23, 31, 30, 32, 32, 5, 32, 14, 37, 35, 2, 15, 18, 6, 29, 3, 9, 20, 19, 26, 10, 37, 35, 31, 30, 26, 5, 32, 23, 21, 14, 2, 0, 15, 4, 29, 36, 12, 26, 6, 3, 1, 8, 17, 18, 27, 24, 10, 37, 23, 31, 30, 5, 32, 21, 14, 21, 35, 2, 15, 18, 6, 29, 3, 16, 19, 26, 22, 5, 2, 31, 30, 32, 23, 21, 14, 14, 14, 37, 35, 10, 15, 4, 29, 12, 6, 3, 1, 18, 17, 24, 10, 37, 23, 31, 30, 5, 32, 14, 35, 2, 0, 0, 15, 18, 6, 29, 3, 34, 19, 26, 10, 37, 35, 31, 30, 5, 32, 23, 21, 14, 2, 15, 4, 12, 24, 24, 29, 6, 3, 1, 18, 17, 24, 10, 23, 31, 30, 5, 32, 14, 37, 35, 2, 15, 19, 19, 18, 6, 11, 29]]
# 58834
# 23663
# [[3.0, 3.0], [5.0, 5.0], [9.0, 9.0], [8.0, 9.0], [4.0, 4.0], [9.0, 9.0], [1.0, 1.0], [8.0, 8.0], [1.0, 1.0], [1.0, 1.0], [9.0, 9.0], [1.0, 1.0], [5.0, 5.0], [1.0, 1.0], [11.0, 11.0], [9.0, 9.0], [1.0, 1.0], [5.0, 4.0], [9.0, 9.0], [7.0, 7.0], [1.0, 1.0], [7.0, 7.0], [2.0, 2.0], [9.0, 9.0], [6.0, 6.0], [1.0, 1.0], [6.0, 6.0], [2.0, 2.0], [1.0, 1.0], [8.0, 8.0], [9.0, 9.0], [9.0, 9.0], [11.0, 11.0], [1.0, 1.0], [1.0, 1.0], [9.0, 9.0], [9.0, 9.0]]

# %%
import random 


torch.manual_seed(12345)
random.shuffle(DataList)

dataset = DataList


train_size = int(lenugl*.70)

#print(int(train_size))


train_dataset = dataset[:train_size]
test_dataset = dataset[train_size:lenugl]

print(f'Number of training graphs: {len(train_dataset)}')
print(f'Number of test graphs: {len(test_dataset)}')
# Out:
# Number of training graphs: 57747
# Number of test graphs: 24750

# %%
from torch_geometric.data import DataLoader

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset,batch_size=128, shuffle=False)

for step, data in enumerate(train_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch_geometric/deprecation.py:12: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Step 1:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2078, 2], edge_index=[2, 12736], y=[64], batch=[2078], ptr=[65])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1736, 2], edge_index=[2, 12736], y=[64], batch=[1736], ptr=[65])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1956, 2], edge_index=[2, 12736], y=[64], batch=[1956], ptr=[65])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2042, 2], edge_index=[2, 12736], y=[64], batch=[2042], ptr=[65])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2000, 2], edge_index=[2, 12736], y=[64], batch=[2000], ptr=[65])
#
# Step 6:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1880, 2], edge_index=[2, 12736], y=[64], batch=[1880], ptr=[65])
#
# Step 7:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2036, 2], edge_index=[2, 12736], y=[64], batch=[2036], ptr=[65])
#
# Step 8:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2082, 2], edge_index=[2, 12736], y=[64], batch=[2082], ptr=[65])
#
# Step 9:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1899, 2], edge_index=[2, 12736], y=[64], batch=[1899], ptr=[65])
#
# Step 10:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1849, 2], edge_index=[2, 12736], y=[64], batch=[1849], ptr=[65])
#
# Step 11:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2150, 2], edge_index=[2, 12736], y=[64], batch=[2150], ptr=[65])
#
# Step 12:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1990, 2], edge_index=[2, 12736], y=[64], batch=[1990], ptr=[65])
#
# Step 13:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2027, 2], edge_index=[2, 12736], y=[64], batch=[2027], ptr=[65])
#
# Step 14:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1719, 2], edge_index=[2, 12736], y=[64], batch=[1719], ptr=[65])
#
# Step 15:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1936, 2], edge_index=[2, 12736], y=[64], batch=[1936], ptr=[65])
#
# Step 16:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1839, 2], edge_index=[2, 12736], y=[64], batch=[1839], ptr=[65])
#
# Step 17:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2025, 2], edge_index=[2, 12736], y=[64], batch=[2025], ptr=[65])
#
# Step 18:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2188, 2], edge_index=[2, 12736], y=[64], batch=[2188], ptr=[65])
#
# Step 19:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1897, 2], edge_index=[2, 12736], y=[64], batch=[1897], ptr=[65])
#
# Step 20:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2064, 2], edge_index=[2, 12736], y=[64], batch=[2064], ptr=[65])
#
# Step 21:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2043, 2], edge_index=[2, 12736], y=[64], batch=[2043], ptr=[65])
#
# Step 22:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1715, 2], edge_index=[2, 12736], y=[64], batch=[1715], ptr=[65])
#
# Step 23:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2086, 2], edge_index=[2, 12736], y=[64], batch=[2086], ptr=[65])
#
# Step 24:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1861, 2], edge_index=[2, 12736], y=[64], batch=[1861], ptr=[65])
#
# Step 25:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1903, 2], edge_index=[2, 12736], y=[64], batch=[1903], ptr=[65])
#
# Step 26:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2028, 2], edge_index=[2, 12736], y=[64], batch=[2028], ptr=[65])
#
# Step 27:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1744, 2], edge_index=[2, 12736], y=[64], batch=[1744], ptr=[65])
#
# Step 28:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1654, 2], edge_index=[2, 12736], y=[64], batch=[1654], ptr=[65])
#
# Step 29:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1854, 2], edge_index=[2, 12736], y=[64], batch=[1854], ptr=[65])
#
# Step 30:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1988, 2], edge_index=[2, 12736], y=[64], batch=[1988], ptr=[65])
#
# Step 31:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2162, 2], edge_index=[2, 12736], y=[64], batch=[2162], ptr=[65])
#
# Step 32:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1931, 2], edge_index=[2, 12736], y=[64], batch=[1931], ptr=[65])
#
# Step 33:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2036, 2], edge_index=[2, 12736], y=[64], batch=[2036], ptr=[65])
#
# Step 34:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2006, 2], edge_index=[2, 12736], y=[64], batch=[2006], ptr=[65])
#
# Step 35:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1806, 2], edge_index=[2, 12736], y=[64], batch=[1806], ptr=[65])
#
# Step 36:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2139, 2], edge_index=[2, 12736], y=[64], batch=[2139], ptr=[65])
#
# Step 37:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2030, 2], edge_index=[2, 12736], y=[64], batch=[2030], ptr=[65])
#
# Step 38:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1843, 2], edge_index=[2, 12736], y=[64], batch=[1843], ptr=[65])
#
# Step 39:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1807, 2], edge_index=[2, 12736], y=[64], batch=[1807], ptr=[65])
#
# Step 40:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1915, 2], edge_index=[2, 12736], y=[64], batch=[1915], ptr=[65])
#
# Step 41:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1811, 2], edge_index=[2, 12736], y=[64], batch=[1811], ptr=[65])
#
# Step 42:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1870, 2], edge_index=[2, 12736], y=[64], batch=[1870], ptr=[65])
#
# Step 43:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2125, 2], edge_index=[2, 12736], y=[64], batch=[2125], ptr=[65])
#
# Step 44:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1911, 2], edge_index=[2, 12736], y=[64], batch=[1911], ptr=[65])
#
# Step 45:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1980, 2], edge_index=[2, 12736], y=[64], batch=[1980], ptr=[65])
#
# Step 46:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2029, 2], edge_index=[2, 12736], y=[64], batch=[2029], ptr=[65])
#
# Step 47:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1991, 2], edge_index=[2, 12736], y=[64], batch=[1991], ptr=[65])
#
# Step 48:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1915, 2], edge_index=[2, 12736], y=[64], batch=[1915], ptr=[65])
#
# Step 49:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1909, 2], edge_index=[2, 12736], y=[64], batch=[1909], ptr=[65])
#
# Step 50:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1955, 2], edge_index=[2, 12736], y=[64], batch=[1955], ptr=[65])
#
# Step 51:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1834, 2], edge_index=[2, 12736], y=[64], batch=[1834], ptr=[65])
#
# Step 52:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1841, 2], edge_index=[2, 12736], y=[64], batch=[1841], ptr=[65])
#
# Step 53:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1962, 2], edge_index=[2, 12736], y=[64], batch=[1962], ptr=[65])
#
# Step 54:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1870, 2], edge_index=[2, 12736], y=[64], batch=[1870], ptr=[65])
#
# Step 55:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1869, 2], edge_index=[2, 12736], y=[64], batch=[1869], ptr=[65])
#
# Step 56:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2093, 2], edge_index=[2, 12736], y=[64], batch=[2093], ptr=[65])
#
# Step 57:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1793, 2], edge_index=[2, 12736], y=[64], batch=[1793], ptr=[65])
#
# Step 58:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2064, 2], edge_index=[2, 12736], y=[64], batch=[2064], ptr=[65])
#
# Step 59:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2213, 2], edge_index=[2, 12736], y=[64], batch=[2213], ptr=[65])
#
# Step 60:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2023, 2], edge_index=[2, 12736], y=[64], batch=[2023], ptr=[65])
#
# Step 61:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1873, 2], edge_index=[2, 12736], y=[64], batch=[1873], ptr=[65])
#
# Step 62:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1875, 2], edge_index=[2, 12736], y=[64], batch=[1875], ptr=[65])
#
# Step 63:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1828, 2], edge_index=[2, 12736], y=[64], batch=[1828], ptr=[65])
#
# Step 64:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2120, 2], edge_index=[2, 12736], y=[64], batch=[2120], ptr=[65])
#
# Step 65:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2062, 2], edge_index=[2, 12736], y=[64], batch=[2062], ptr=[65])
#
# Step 66:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1865, 2], edge_index=[2, 12736], y=[64], batch=[1865], ptr=[65])
#
# Step 67:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2281, 2], edge_index=[2, 12736], y=[64], batch=[2281], ptr=[65])
#
# Step 68:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2099, 2], edge_index=[2, 12736], y=[64], batch=[2099], ptr=[65])
#
# Step 69:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1766, 2], edge_index=[2, 12736], y=[64], batch=[1766], ptr=[65])
#
# Step 70:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2182, 2], edge_index=[2, 12736], y=[64], batch=[2182], ptr=[65])
#
# Step 71:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2183, 2], edge_index=[2, 12736], y=[64], batch=[2183], ptr=[65])
#
# Step 72:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1918, 2], edge_index=[2, 12736], y=[64], batch=[1918], ptr=[65])
#
# Step 73:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1942, 2], edge_index=[2, 12736], y=[64], batch=[1942], ptr=[65])
#
# Step 74:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1905, 2], edge_index=[2, 12736], y=[64], batch=[1905], ptr=[65])
#
# Step 75:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1573, 2], edge_index=[2, 12736], y=[64], batch=[1573], ptr=[65])
#
# Step 76:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2088, 2], edge_index=[2, 12736], y=[64], batch=[2088], ptr=[65])
#
# Step 77:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1888, 2], edge_index=[2, 12736], y=[64], batch=[1888], ptr=[65])
#
# Step 78:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1826, 2], edge_index=[2, 12736], y=[64], batch=[1826], ptr=[65])
#
# Step 79:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1898, 2], edge_index=[2, 12736], y=[64], batch=[1898], ptr=[65])
#
# Step 80:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2080, 2], edge_index=[2, 12736], y=[64], batch=[2080], ptr=[65])
#
# Step 81:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2019, 2], edge_index=[2, 12736], y=[64], batch=[2019], ptr=[65])
#
# Step 82:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1841, 2], edge_index=[2, 12736], y=[64], batch=[1841], ptr=[65])
#
# Step 83:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1690, 2], edge_index=[2, 12736], y=[64], batch=[1690], ptr=[65])
#
# Step 84:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1765, 2], edge_index=[2, 12736], y=[64], batch=[1765], ptr=[65])
#
# Step 85:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1888, 2], edge_index=[2, 12736], y=[64], batch=[1888], ptr=[65])
#
# Step 86:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1838, 2], edge_index=[2, 12736], y=[64], batch=[1838], ptr=[65])
#
# Step 87:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1837, 2], edge_index=[2, 12736], y=[64], batch=[1837], ptr=[65])
#
# Step 88:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2068, 2], edge_index=[2, 12736], y=[64], batch=[2068], ptr=[65])
#
# Step 89:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1964, 2], edge_index=[2, 12736], y=[64], batch=[1964], ptr=[65])
#
# Step 90:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1804, 2], edge_index=[2, 12736], y=[64], batch=[1804], ptr=[65])
#
# Step 91:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2064, 2], edge_index=[2, 12736], y=[64], batch=[2064], ptr=[65])
#
# Step 92:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1790, 2], edge_index=[2, 12736], y=[64], batch=[1790], ptr=[65])
#
# Step 93:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1815, 2], edge_index=[2, 12736], y=[64], batch=[1815], ptr=[65])
#
# Step 94:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1914, 2], edge_index=[2, 12736], y=[64], batch=[1914], ptr=[65])
#
# Step 95:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2033, 2], edge_index=[2, 12736], y=[64], batch=[2033], ptr=[65])
#
# Step 96:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2101, 2], edge_index=[2, 12736], y=[64], batch=[2101], ptr=[65])
#
# Step 97:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1824, 2], edge_index=[2, 12736], y=[64], batch=[1824], ptr=[65])
#
# Step 98:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1959, 2], edge_index=[2, 12736], y=[64], batch=[1959], ptr=[65])
#
# Step 99:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1940, 2], edge_index=[2, 12736], y=[64], batch=[1940], ptr=[65])
#
# Step 100:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2017, 2], edge_index=[2, 12736], y=[64], batch=[2017], ptr=[65])
#
# Step 101:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1844, 2], edge_index=[2, 12736], y=[64], batch=[1844], ptr=[65])
#
# Step 102:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2232, 2], edge_index=[2, 12736], y=[64], batch=[2232], ptr=[65])
#
# Step 103:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2064, 2], edge_index=[2, 12736], y=[64], batch=[2064], ptr=[65])
#
# Step 104:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1797, 2], edge_index=[2, 12736], y=[64], batch=[1797], ptr=[65])
#
# Step 105:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1879, 2], edge_index=[2, 12736], y=[64], batch=[1879], ptr=[65])
#
# Step 106:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1863, 2], edge_index=[2, 12736], y=[64], batch=[1863], ptr=[65])
#
# Step 107:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2023, 2], edge_index=[2, 12736], y=[64], batch=[2023], ptr=[65])
#
# Step 108:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1646, 2], edge_index=[2, 12736], y=[64], batch=[1646], ptr=[65])
#
# Step 109:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1718, 2], edge_index=[2, 12736], y=[64], batch=[1718], ptr=[65])
#
# Step 110:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2157, 2], edge_index=[2, 12736], y=[64], batch=[2157], ptr=[65])
#
# Step 111:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2093, 2], edge_index=[2, 12736], y=[64], batch=[2093], ptr=[65])
#
# Step 112:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2111, 2], edge_index=[2, 12736], y=[64], batch=[2111], ptr=[65])
#
# Step 113:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1608, 2], edge_index=[2, 12736], y=[64], batch=[1608], ptr=[65])
#
# Step 114:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1796, 2], edge_index=[2, 12736], y=[64], batch=[1796], ptr=[65])
#
# Step 115:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1792, 2], edge_index=[2, 12736], y=[64], batch=[1792], ptr=[65])
#
# Step 116:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1780, 2], edge_index=[2, 12736], y=[64], batch=[1780], ptr=[65])
#
# Step 117:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1891, 2], edge_index=[2, 12736], y=[64], batch=[1891], ptr=[65])
#
# Step 118:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1805, 2], edge_index=[2, 12736], y=[64], batch=[1805], ptr=[65])
#
# Step 119:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2033, 2], edge_index=[2, 12736], y=[64], batch=[2033], ptr=[65])
#
# Step 120:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2464, 2], edge_index=[2, 12736], y=[64], batch=[2464], ptr=[65])
#
# Step 121:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1719, 2], edge_index=[2, 12736], y=[64], batch=[1719], ptr=[65])
#
# Step 122:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1936, 2], edge_index=[2, 12736], y=[64], batch=[1936], ptr=[65])
#
# Step 123:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2113, 2], edge_index=[2, 12736], y=[64], batch=[2113], ptr=[65])
#
# Step 124:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1969, 2], edge_index=[2, 12736], y=[64], batch=[1969], ptr=[65])
#
# Step 125:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1730, 2], edge_index=[2, 12736], y=[64], batch=[1730], ptr=[65])
#
# Step 126:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1712, 2], edge_index=[2, 12736], y=[64], batch=[1712], ptr=[65])
#
# Step 127:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1952, 2], edge_index=[2, 12736], y=[64], batch=[1952], ptr=[65])
#
# Step 128:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2162, 2], edge_index=[2, 12736], y=[64], batch=[2162], ptr=[65])
#
# Step 129:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2013, 2], edge_index=[2, 12736], y=[64], batch=[2013], ptr=[65])
#
# Step 130:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2155, 2], edge_index=[2, 12736], y=[64], batch=[2155], ptr=[65])
#
# Step 131:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2101, 2], edge_index=[2, 12736], y=[64], batch=[2101], ptr=[65])
#
# Step 132:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2169, 2], edge_index=[2, 12736], y=[64], batch=[2169], ptr=[65])
#
# Step 133:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1881, 2], edge_index=[2, 12736], y=[64], batch=[1881], ptr=[65])
#
# Step 134:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1955, 2], edge_index=[2, 12736], y=[64], batch=[1955], ptr=[65])
#
# Step 135:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1638, 2], edge_index=[2, 12736], y=[64], batch=[1638], ptr=[65])
#
# Step 136:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2087, 2], edge_index=[2, 12736], y=[64], batch=[2087], ptr=[65])
#
# Step 137:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2068, 2], edge_index=[2, 12736], y=[64], batch=[2068], ptr=[65])
#
# Step 138:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1849, 2], edge_index=[2, 12736], y=[64], batch=[1849], ptr=[65])
#
# Step 139:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1648, 2], edge_index=[2, 12736], y=[64], batch=[1648], ptr=[65])
#
# Step 140:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1852, 2], edge_index=[2, 12736], y=[64], batch=[1852], ptr=[65])
#
# Step 141:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1777, 2], edge_index=[2, 12736], y=[64], batch=[1777], ptr=[65])
#
# Step 142:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1850, 2], edge_index=[2, 12736], y=[64], batch=[1850], ptr=[65])
#
# Step 143:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1893, 2], edge_index=[2, 12736], y=[64], batch=[1893], ptr=[65])
#
# Step 144:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2130, 2], edge_index=[2, 12736], y=[64], batch=[2130], ptr=[65])
#
# Step 145:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1900, 2], edge_index=[2, 12736], y=[64], batch=[1900], ptr=[65])
#
# Step 146:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2008, 2], edge_index=[2, 12736], y=[64], batch=[2008], ptr=[65])
#
# Step 147:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2007, 2], edge_index=[2, 12736], y=[64], batch=[2007], ptr=[65])
#
# Step 148:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2098, 2], edge_index=[2, 12736], y=[64], batch=[2098], ptr=[65])
#
# Step 149:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1948, 2], edge_index=[2, 12736], y=[64], batch=[1948], ptr=[65])
#
# Step 150:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2326, 2], edge_index=[2, 12736], y=[64], batch=[2326], ptr=[65])
#
# Step 151:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2198, 2], edge_index=[2, 12736], y=[64], batch=[2198], ptr=[65])
#
# Step 152:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2002, 2], edge_index=[2, 12736], y=[64], batch=[2002], ptr=[65])
#
# Step 153:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1792, 2], edge_index=[2, 12736], y=[64], batch=[1792], ptr=[65])
#
# Step 154:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1715, 2], edge_index=[2, 12736], y=[64], batch=[1715], ptr=[65])
#
# Step 155:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1790, 2], edge_index=[2, 12736], y=[64], batch=[1790], ptr=[65])
#
# Step 156:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2055, 2], edge_index=[2, 12736], y=[64], batch=[2055], ptr=[65])
#
# Step 157:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1674, 2], edge_index=[2, 12736], y=[64], batch=[1674], ptr=[65])
#
# Step 158:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2061, 2], edge_index=[2, 12736], y=[64], batch=[2061], ptr=[65])
#
# Step 159:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1871, 2], edge_index=[2, 12736], y=[64], batch=[1871], ptr=[65])
#
# Step 160:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2065, 2], edge_index=[2, 12736], y=[64], batch=[2065], ptr=[65])
#
# Step 161:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1936, 2], edge_index=[2, 12736], y=[64], batch=[1936], ptr=[65])
#
# Step 162:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1793, 2], edge_index=[2, 12736], y=[64], batch=[1793], ptr=[65])
#
# Step 163:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2049, 2], edge_index=[2, 12736], y=[64], batch=[2049], ptr=[65])
#
# Step 164:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1913, 2], edge_index=[2, 12736], y=[64], batch=[1913], ptr=[65])
#
# Step 165:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1863, 2], edge_index=[2, 12736], y=[64], batch=[1863], ptr=[65])
#
# Step 166:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1906, 2], edge_index=[2, 12736], y=[64], batch=[1906], ptr=[65])
#
# Step 167:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1950, 2], edge_index=[2, 12736], y=[64], batch=[1950], ptr=[65])
#
# Step 168:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2035, 2], edge_index=[2, 12736], y=[64], batch=[2035], ptr=[65])
#
# Step 169:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1939, 2], edge_index=[2, 12736], y=[64], batch=[1939], ptr=[65])
#
# Step 170:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1870, 2], edge_index=[2, 12736], y=[64], batch=[1870], ptr=[65])
#
# Step 171:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1771, 2], edge_index=[2, 12736], y=[64], batch=[1771], ptr=[65])
#
# Step 172:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1957, 2], edge_index=[2, 12736], y=[64], batch=[1957], ptr=[65])
#
# Step 173:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1941, 2], edge_index=[2, 12736], y=[64], batch=[1941], ptr=[65])
#
# Step 174:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1654, 2], edge_index=[2, 12736], y=[64], batch=[1654], ptr=[65])
#
# Step 175:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2031, 2], edge_index=[2, 12736], y=[64], batch=[2031], ptr=[65])
#
# Step 176:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2188, 2], edge_index=[2, 12736], y=[64], batch=[2188], ptr=[65])
#
# Step 177:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1762, 2], edge_index=[2, 12736], y=[64], batch=[1762], ptr=[65])
#
# Step 178:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1795, 2], edge_index=[2, 12736], y=[64], batch=[1795], ptr=[65])
#
# Step 179:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2079, 2], edge_index=[2, 12736], y=[64], batch=[2079], ptr=[65])
#
# Step 180:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1995, 2], edge_index=[2, 12736], y=[64], batch=[1995], ptr=[65])
#
# Step 181:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1911, 2], edge_index=[2, 12736], y=[64], batch=[1911], ptr=[65])
#
# Step 182:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2016, 2], edge_index=[2, 12736], y=[64], batch=[2016], ptr=[65])
#
# Step 183:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2141, 2], edge_index=[2, 12736], y=[64], batch=[2141], ptr=[65])
#
# Step 184:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1849, 2], edge_index=[2, 12736], y=[64], batch=[1849], ptr=[65])
#
# Step 185:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2000, 2], edge_index=[2, 12736], y=[64], batch=[2000], ptr=[65])
#
# Step 186:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1956, 2], edge_index=[2, 12736], y=[64], batch=[1956], ptr=[65])
#
# Step 187:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2057, 2], edge_index=[2, 12736], y=[64], batch=[2057], ptr=[65])
#
# Step 188:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2481, 2], edge_index=[2, 12736], y=[64], batch=[2481], ptr=[65])
#
# Step 189:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1880, 2], edge_index=[2, 12736], y=[64], batch=[1880], ptr=[65])
#
# Step 190:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1881, 2], edge_index=[2, 12736], y=[64], batch=[1881], ptr=[65])
#
# Step 191:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1738, 2], edge_index=[2, 12736], y=[64], batch=[1738], ptr=[65])
#
# Step 192:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1788, 2], edge_index=[2, 12736], y=[64], batch=[1788], ptr=[65])
#
# Step 193:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1794, 2], edge_index=[2, 12736], y=[64], batch=[1794], ptr=[65])
#
# Step 194:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2043, 2], edge_index=[2, 12736], y=[64], batch=[2043], ptr=[65])
#
# Step 195:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1884, 2], edge_index=[2, 12736], y=[64], batch=[1884], ptr=[65])
#
# Step 196:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1775, 2], edge_index=[2, 12736], y=[64], batch=[1775], ptr=[65])
#
# Step 197:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1783, 2], edge_index=[2, 12736], y=[64], batch=[1783], ptr=[65])
#
# Step 198:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2444, 2], edge_index=[2, 12736], y=[64], batch=[2444], ptr=[65])
#
# Step 199:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1744, 2], edge_index=[2, 12736], y=[64], batch=[1744], ptr=[65])
#
# Step 200:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1848, 2], edge_index=[2, 12736], y=[64], batch=[1848], ptr=[65])
#
# Step 201:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1966, 2], edge_index=[2, 12736], y=[64], batch=[1966], ptr=[65])
#
# Step 202:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2034, 2], edge_index=[2, 12736], y=[64], batch=[2034], ptr=[65])
#
# Step 203:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2462, 2], edge_index=[2, 12736], y=[64], batch=[2462], ptr=[65])
#
# Step 204:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1927, 2], edge_index=[2, 12736], y=[64], batch=[1927], ptr=[65])
#
# Step 205:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1819, 2], edge_index=[2, 12736], y=[64], batch=[1819], ptr=[65])
#
# Step 206:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1919, 2], edge_index=[2, 12736], y=[64], batch=[1919], ptr=[65])
#
# Step 207:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1814, 2], edge_index=[2, 12736], y=[64], batch=[1814], ptr=[65])
#
# Step 208:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1953, 2], edge_index=[2, 12736], y=[64], batch=[1953], ptr=[65])
#
# Step 209:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1917, 2], edge_index=[2, 12736], y=[64], batch=[1917], ptr=[65])
#
# Step 210:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2025, 2], edge_index=[2, 12736], y=[64], batch=[2025], ptr=[65])
#
# Step 211:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2028, 2], edge_index=[2, 12736], y=[64], batch=[2028], ptr=[65])
#
# Step 212:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1992, 2], edge_index=[2, 12736], y=[64], batch=[1992], ptr=[65])
#
# Step 213:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1950, 2], edge_index=[2, 12736], y=[64], batch=[1950], ptr=[65])
#
# Step 214:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2151, 2], edge_index=[2, 12736], y=[64], batch=[2151], ptr=[65])
#
# Step 215:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1853, 2], edge_index=[2, 12736], y=[64], batch=[1853], ptr=[65])
#
# Step 216:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1818, 2], edge_index=[2, 12736], y=[64], batch=[1818], ptr=[65])
#
# Step 217:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2003, 2], edge_index=[2, 12736], y=[64], batch=[2003], ptr=[65])
#
# Step 218:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2282, 2], edge_index=[2, 12736], y=[64], batch=[2282], ptr=[65])
#
# Step 219:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2103, 2], edge_index=[2, 12736], y=[64], batch=[2103], ptr=[65])
#
# Step 220:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2205, 2], edge_index=[2, 12736], y=[64], batch=[2205], ptr=[65])
#
# Step 221:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1696, 2], edge_index=[2, 12736], y=[64], batch=[1696], ptr=[65])
#
# Step 222:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2174, 2], edge_index=[2, 12736], y=[64], batch=[2174], ptr=[65])
#
# Step 223:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1811, 2], edge_index=[2, 12736], y=[64], batch=[1811], ptr=[65])
#
# Step 224:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1852, 2], edge_index=[2, 12736], y=[64], batch=[1852], ptr=[65])
#
# Step 225:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2246, 2], edge_index=[2, 12736], y=[64], batch=[2246], ptr=[65])
#
# Step 226:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2183, 2], edge_index=[2, 12736], y=[64], batch=[2183], ptr=[65])
#
# Step 227:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2039, 2], edge_index=[2, 12736], y=[64], batch=[2039], ptr=[65])
#
# Step 228:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2006, 2], edge_index=[2, 12736], y=[64], batch=[2006], ptr=[65])
#
# Step 229:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1947, 2], edge_index=[2, 12736], y=[64], batch=[1947], ptr=[65])
#
# Step 230:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2131, 2], edge_index=[2, 12736], y=[64], batch=[2131], ptr=[65])
#
# Step 231:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1779, 2], edge_index=[2, 12736], y=[64], batch=[1779], ptr=[65])
#
# Step 232:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1944, 2], edge_index=[2, 12736], y=[64], batch=[1944], ptr=[65])
#
# Step 233:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1638, 2], edge_index=[2, 12736], y=[64], batch=[1638], ptr=[65])
#
# Step 234:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1972, 2], edge_index=[2, 12736], y=[64], batch=[1972], ptr=[65])
#
# Step 235:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1902, 2], edge_index=[2, 12736], y=[64], batch=[1902], ptr=[65])
#
# Step 236:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2215, 2], edge_index=[2, 12736], y=[64], batch=[2215], ptr=[65])
#
# Step 237:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2001, 2], edge_index=[2, 12736], y=[64], batch=[2001], ptr=[65])
#
# Step 238:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1949, 2], edge_index=[2, 12736], y=[64], batch=[1949], ptr=[65])
#
# Step 239:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1680, 2], edge_index=[2, 12736], y=[64], batch=[1680], ptr=[65])
#
# Step 240:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1794, 2], edge_index=[2, 12736], y=[64], batch=[1794], ptr=[65])
#
# Step 241:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1652, 2], edge_index=[2, 12736], y=[64], batch=[1652], ptr=[65])
#
# Step 242:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1688, 2], edge_index=[2, 12736], y=[64], batch=[1688], ptr=[65])
#
# Step 243:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2020, 2], edge_index=[2, 12736], y=[64], batch=[2020], ptr=[65])
#
# Step 244:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1900, 2], edge_index=[2, 12736], y=[64], batch=[1900], ptr=[65])
#
# Step 245:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1908, 2], edge_index=[2, 12736], y=[64], batch=[1908], ptr=[65])
#
# Step 246:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1842, 2], edge_index=[2, 12736], y=[64], batch=[1842], ptr=[65])
#
# Step 247:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1960, 2], edge_index=[2, 12736], y=[64], batch=[1960], ptr=[65])
#
# Step 248:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2020, 2], edge_index=[2, 12736], y=[64], batch=[2020], ptr=[65])
#
# Step 249:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1944, 2], edge_index=[2, 12736], y=[64], batch=[1944], ptr=[65])
#
# Step 250:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1683, 2], edge_index=[2, 12736], y=[64], batch=[1683], ptr=[65])
#
# Step 251:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2316, 2], edge_index=[2, 12736], y=[64], batch=[2316], ptr=[65])
#
# Step 252:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2051, 2], edge_index=[2, 12736], y=[64], batch=[2051], ptr=[65])
#
# Step 253:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2168, 2], edge_index=[2, 12736], y=[64], batch=[2168], ptr=[65])
#
# Step 254:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1782, 2], edge_index=[2, 12736], y=[64], batch=[1782], ptr=[65])
#
# Step 255:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1852, 2], edge_index=[2, 12736], y=[64], batch=[1852], ptr=[65])
#
# Step 256:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2128, 2], edge_index=[2, 12736], y=[64], batch=[2128], ptr=[65])
#
# Step 257:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1675, 2], edge_index=[2, 12736], y=[64], batch=[1675], ptr=[65])
#
# Step 258:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1714, 2], edge_index=[2, 12736], y=[64], batch=[1714], ptr=[65])
#
# Step 259:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1898, 2], edge_index=[2, 12736], y=[64], batch=[1898], ptr=[65])
#
# Step 260:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1777, 2], edge_index=[2, 12736], y=[64], batch=[1777], ptr=[65])
#
# Step 261:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1997, 2], edge_index=[2, 12736], y=[64], batch=[1997], ptr=[65])
#
# Step 262:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2030, 2], edge_index=[2, 12736], y=[64], batch=[2030], ptr=[65])
#
# Step 263:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1860, 2], edge_index=[2, 12736], y=[64], batch=[1860], ptr=[65])
#
# Step 264:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1759, 2], edge_index=[2, 12736], y=[64], batch=[1759], ptr=[65])
#
# Step 265:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2069, 2], edge_index=[2, 12736], y=[64], batch=[2069], ptr=[65])
#
# Step 266:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1667, 2], edge_index=[2, 12736], y=[64], batch=[1667], ptr=[65])
#
# Step 267:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1765, 2], edge_index=[2, 12736], y=[64], batch=[1765], ptr=[65])
#
# Step 268:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1895, 2], edge_index=[2, 12736], y=[64], batch=[1895], ptr=[65])
#
# Step 269:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2253, 2], edge_index=[2, 12736], y=[64], batch=[2253], ptr=[65])
#
# Step 270:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2032, 2], edge_index=[2, 12736], y=[64], batch=[2032], ptr=[65])
#
# Step 271:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1801, 2], edge_index=[2, 12736], y=[64], batch=[1801], ptr=[65])
#
# Step 272:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1843, 2], edge_index=[2, 12736], y=[64], batch=[1843], ptr=[65])
#
# Step 273:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1864, 2], edge_index=[2, 12736], y=[64], batch=[1864], ptr=[65])
#
# Step 274:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1857, 2], edge_index=[2, 12736], y=[64], batch=[1857], ptr=[65])
#
# Step 275:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1819, 2], edge_index=[2, 12736], y=[64], batch=[1819], ptr=[65])
#
# Step 276:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2054, 2], edge_index=[2, 12736], y=[64], batch=[2054], ptr=[65])
#
# Step 277:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1933, 2], edge_index=[2, 12736], y=[64], batch=[1933], ptr=[65])
#
# Step 278:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1939, 2], edge_index=[2, 12736], y=[64], batch=[1939], ptr=[65])
#
# Step 279:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1874, 2], edge_index=[2, 12736], y=[64], batch=[1874], ptr=[65])
#
# Step 280:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2304, 2], edge_index=[2, 12736], y=[64], batch=[2304], ptr=[65])
#
# Step 281:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2232, 2], edge_index=[2, 12736], y=[64], batch=[2232], ptr=[65])
#
# Step 282:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2093, 2], edge_index=[2, 12736], y=[64], batch=[2093], ptr=[65])
#
# Step 283:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2147, 2], edge_index=[2, 12736], y=[64], batch=[2147], ptr=[65])
#
# Step 284:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1885, 2], edge_index=[2, 12736], y=[64], batch=[1885], ptr=[65])
#
# Step 285:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2010, 2], edge_index=[2, 12736], y=[64], batch=[2010], ptr=[65])
#
# Step 286:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2025, 2], edge_index=[2, 12736], y=[64], batch=[2025], ptr=[65])
#
# Step 287:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2051, 2], edge_index=[2, 12736], y=[64], batch=[2051], ptr=[65])
#
# Step 288:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1905, 2], edge_index=[2, 12736], y=[64], batch=[1905], ptr=[65])
#
# Step 289:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1849, 2], edge_index=[2, 12736], y=[64], batch=[1849], ptr=[65])
#
# Step 290:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2142, 2], edge_index=[2, 12736], y=[64], batch=[2142], ptr=[65])
#
# Step 291:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1785, 2], edge_index=[2, 12736], y=[64], batch=[1785], ptr=[65])
#
# Step 292:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2307, 2], edge_index=[2, 12736], y=[64], batch=[2307], ptr=[65])
#
# Step 293:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1785, 2], edge_index=[2, 12736], y=[64], batch=[1785], ptr=[65])
#
# Step 294:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1976, 2], edge_index=[2, 12736], y=[64], batch=[1976], ptr=[65])
#
# Step 295:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2081, 2], edge_index=[2, 12736], y=[64], batch=[2081], ptr=[65])
#
# Step 296:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1893, 2], edge_index=[2, 12736], y=[64], batch=[1893], ptr=[65])
#
# Step 297:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2035, 2], edge_index=[2, 12736], y=[64], batch=[2035], ptr=[65])
#
# Step 298:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2191, 2], edge_index=[2, 12736], y=[64], batch=[2191], ptr=[65])
#
# Step 299:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1858, 2], edge_index=[2, 12736], y=[64], batch=[1858], ptr=[65])
#
# Step 300:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1835, 2], edge_index=[2, 12736], y=[64], batch=[1835], ptr=[65])
#
# Step 301:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1812, 2], edge_index=[2, 12736], y=[64], batch=[1812], ptr=[65])
#
# Step 302:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1854, 2], edge_index=[2, 12736], y=[64], batch=[1854], ptr=[65])
#
# Step 303:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1852, 2], edge_index=[2, 12736], y=[64], batch=[1852], ptr=[65])
#
# Step 304:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2406, 2], edge_index=[2, 12736], y=[64], batch=[2406], ptr=[65])
#
# Step 305:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1885, 2], edge_index=[2, 12736], y=[64], batch=[1885], ptr=[65])
#
# Step 306:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1658, 2], edge_index=[2, 12736], y=[64], batch=[1658], ptr=[65])
#
# Step 307:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2417, 2], edge_index=[2, 12736], y=[64], batch=[2417], ptr=[65])
#
# Step 308:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2409, 2], edge_index=[2, 12736], y=[64], batch=[2409], ptr=[65])
#
# Step 309:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1982, 2], edge_index=[2, 12736], y=[64], batch=[1982], ptr=[65])
#
# Step 310:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2188, 2], edge_index=[2, 12736], y=[64], batch=[2188], ptr=[65])
#
# Step 311:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2037, 2], edge_index=[2, 12736], y=[64], batch=[2037], ptr=[65])
#
# Step 312:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1910, 2], edge_index=[2, 12736], y=[64], batch=[1910], ptr=[65])
#
# Step 313:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2032, 2], edge_index=[2, 12736], y=[64], batch=[2032], ptr=[65])
#
# Step 314:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1586, 2], edge_index=[2, 12736], y=[64], batch=[1586], ptr=[65])
#
# Step 315:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2102, 2], edge_index=[2, 12736], y=[64], batch=[2102], ptr=[65])
#
# Step 316:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1850, 2], edge_index=[2, 12736], y=[64], batch=[1850], ptr=[65])
#
# Step 317:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1997, 2], edge_index=[2, 12736], y=[64], batch=[1997], ptr=[65])
#
# Step 318:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1795, 2], edge_index=[2, 12736], y=[64], batch=[1795], ptr=[65])
#
# Step 319:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1969, 2], edge_index=[2, 12736], y=[64], batch=[1969], ptr=[65])
#
# Step 320:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1791, 2], edge_index=[2, 12736], y=[64], batch=[1791], ptr=[65])
#
# Step 321:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2302, 2], edge_index=[2, 12736], y=[64], batch=[2302], ptr=[65])
#
# Step 322:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1738, 2], edge_index=[2, 12736], y=[64], batch=[1738], ptr=[65])
#
# Step 323:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1932, 2], edge_index=[2, 12736], y=[64], batch=[1932], ptr=[65])
#
# Step 324:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1869, 2], edge_index=[2, 12736], y=[64], batch=[1869], ptr=[65])
#
# Step 325:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2085, 2], edge_index=[2, 12736], y=[64], batch=[2085], ptr=[65])
#
# Step 326:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2005, 2], edge_index=[2, 12736], y=[64], batch=[2005], ptr=[65])
#
# Step 327:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1871, 2], edge_index=[2, 12736], y=[64], batch=[1871], ptr=[65])
#
# Step 328:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1930, 2], edge_index=[2, 12736], y=[64], batch=[1930], ptr=[65])
#
# Step 329:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2090, 2], edge_index=[2, 12736], y=[64], batch=[2090], ptr=[65])
#
# Step 330:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2033, 2], edge_index=[2, 12736], y=[64], batch=[2033], ptr=[65])
#
# Step 331:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1857, 2], edge_index=[2, 12736], y=[64], batch=[1857], ptr=[65])
#
# Step 332:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1942, 2], edge_index=[2, 12736], y=[64], batch=[1942], ptr=[65])
#
# Step 333:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2083, 2], edge_index=[2, 12736], y=[64], batch=[2083], ptr=[65])
#
# Step 334:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1813, 2], edge_index=[2, 12736], y=[64], batch=[1813], ptr=[65])
#
# Step 335:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2057, 2], edge_index=[2, 12736], y=[64], batch=[2057], ptr=[65])
#
# Step 336:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1866, 2], edge_index=[2, 12736], y=[64], batch=[1866], ptr=[65])
#
# Step 337:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1977, 2], edge_index=[2, 12736], y=[64], batch=[1977], ptr=[65])
#
# Step 338:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1936, 2], edge_index=[2, 12736], y=[64], batch=[1936], ptr=[65])
#
# Step 339:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1865, 2], edge_index=[2, 12736], y=[64], batch=[1865], ptr=[65])
#
# Step 340:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1989, 2], edge_index=[2, 12736], y=[64], batch=[1989], ptr=[65])
#
# Step 341:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2027, 2], edge_index=[2, 12736], y=[64], batch=[2027], ptr=[65])
#
# Step 342:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2046, 2], edge_index=[2, 12736], y=[64], batch=[2046], ptr=[65])
#
# Step 343:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1996, 2], edge_index=[2, 12736], y=[64], batch=[1996], ptr=[65])
#
# Step 344:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1725, 2], edge_index=[2, 12736], y=[64], batch=[1725], ptr=[65])
#
# Step 345:
# =======
# Number of graphs in the current batch: 64
# ...
#
# Step 789:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1832, 2], edge_index=[2, 12736], y=[64], batch=[1832], ptr=[65])
#
# Step 790:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1935, 2], edge_index=[2, 12736], y=[64], batch=[1935], ptr=[65])
#
# Step 791:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1935, 2], edge_index=[2, 12736], y=[64], batch=[1935], ptr=[65])
#
# Step 792:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1778, 2], edge_index=[2, 12736], y=[64], batch=[1778], ptr=[65])
#
# Step 793:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1631, 2], edge_index=[2, 12736], y=[64], batch=[1631], ptr=[65])
#
# Step 794:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1848, 2], edge_index=[2, 12736], y=[64], batch=[1848], ptr=[65])
#
# Step 795:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1880, 2], edge_index=[2, 12736], y=[64], batch=[1880], ptr=[65])
#
# Step 796:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2027, 2], edge_index=[2, 12736], y=[64], batch=[2027], ptr=[65])
#
# Step 797:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1844, 2], edge_index=[2, 12736], y=[64], batch=[1844], ptr=[65])
#
# Step 798:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1817, 2], edge_index=[2, 12736], y=[64], batch=[1817], ptr=[65])
#
# Step 799:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1629, 2], edge_index=[2, 12736], y=[64], batch=[1629], ptr=[65])
#
# Step 800:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2287, 2], edge_index=[2, 12736], y=[64], batch=[2287], ptr=[65])
#
# Step 801:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2088, 2], edge_index=[2, 12736], y=[64], batch=[2088], ptr=[65])
#
# Step 802:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1664, 2], edge_index=[2, 12736], y=[64], batch=[1664], ptr=[65])
#
# Step 803:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1745, 2], edge_index=[2, 12736], y=[64], batch=[1745], ptr=[65])
#
# Step 804:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1937, 2], edge_index=[2, 12736], y=[64], batch=[1937], ptr=[65])
#
# Step 805:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2070, 2], edge_index=[2, 12736], y=[64], batch=[2070], ptr=[65])
#
# Step 806:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1985, 2], edge_index=[2, 12736], y=[64], batch=[1985], ptr=[65])
#
# Step 807:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1962, 2], edge_index=[2, 12736], y=[64], batch=[1962], ptr=[65])
#
# Step 808:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2048, 2], edge_index=[2, 12736], y=[64], batch=[2048], ptr=[65])
#
# Step 809:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1891, 2], edge_index=[2, 12736], y=[64], batch=[1891], ptr=[65])
#
# Step 810:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1994, 2], edge_index=[2, 12736], y=[64], batch=[1994], ptr=[65])
#
# Step 811:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2250, 2], edge_index=[2, 12736], y=[64], batch=[2250], ptr=[65])
#
# Step 812:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1996, 2], edge_index=[2, 12736], y=[64], batch=[1996], ptr=[65])
#
# Step 813:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2180, 2], edge_index=[2, 12736], y=[64], batch=[2180], ptr=[65])
#
# Step 814:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2114, 2], edge_index=[2, 12736], y=[64], batch=[2114], ptr=[65])
#
# Step 815:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2082, 2], edge_index=[2, 12736], y=[64], batch=[2082], ptr=[65])
#
# Step 816:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1895, 2], edge_index=[2, 12736], y=[64], batch=[1895], ptr=[65])
#
# Step 817:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1759, 2], edge_index=[2, 12736], y=[64], batch=[1759], ptr=[65])
#
# Step 818:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2069, 2], edge_index=[2, 12736], y=[64], batch=[2069], ptr=[65])
#
# Step 819:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1946, 2], edge_index=[2, 12736], y=[64], batch=[1946], ptr=[65])
#
# Step 820:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1870, 2], edge_index=[2, 12736], y=[64], batch=[1870], ptr=[65])
#
# Step 821:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2062, 2], edge_index=[2, 12736], y=[64], batch=[2062], ptr=[65])
#
# Step 822:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2060, 2], edge_index=[2, 12736], y=[64], batch=[2060], ptr=[65])
#
# Step 823:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1823, 2], edge_index=[2, 12736], y=[64], batch=[1823], ptr=[65])
#
# Step 824:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1895, 2], edge_index=[2, 12736], y=[64], batch=[1895], ptr=[65])
#
# Step 825:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1707, 2], edge_index=[2, 12736], y=[64], batch=[1707], ptr=[65])
#
# Step 826:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2446, 2], edge_index=[2, 12736], y=[64], batch=[2446], ptr=[65])
#
# Step 827:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2080, 2], edge_index=[2, 12736], y=[64], batch=[2080], ptr=[65])
#
# Step 828:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2159, 2], edge_index=[2, 12736], y=[64], batch=[2159], ptr=[65])
#
# Step 829:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2083, 2], edge_index=[2, 12736], y=[64], batch=[2083], ptr=[65])
#
# Step 830:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2312, 2], edge_index=[2, 12736], y=[64], batch=[2312], ptr=[65])
#
# Step 831:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1924, 2], edge_index=[2, 12736], y=[64], batch=[1924], ptr=[65])
#
# Step 832:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1751, 2], edge_index=[2, 12736], y=[64], batch=[1751], ptr=[65])
#
# Step 833:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1877, 2], edge_index=[2, 12736], y=[64], batch=[1877], ptr=[65])
#
# Step 834:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1770, 2], edge_index=[2, 12736], y=[64], batch=[1770], ptr=[65])
#
# Step 835:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1926, 2], edge_index=[2, 12736], y=[64], batch=[1926], ptr=[65])
#
# Step 836:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1937, 2], edge_index=[2, 12736], y=[64], batch=[1937], ptr=[65])
#
# Step 837:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2141, 2], edge_index=[2, 12736], y=[64], batch=[2141], ptr=[65])
#
# Step 838:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1735, 2], edge_index=[2, 12736], y=[64], batch=[1735], ptr=[65])
#
# Step 839:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2253, 2], edge_index=[2, 12736], y=[64], batch=[2253], ptr=[65])
#
# Step 840:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1935, 2], edge_index=[2, 12736], y=[64], batch=[1935], ptr=[65])
#
# Step 841:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2037, 2], edge_index=[2, 12736], y=[64], batch=[2037], ptr=[65])
#
# Step 842:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1887, 2], edge_index=[2, 12736], y=[64], batch=[1887], ptr=[65])
#
# Step 843:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1624, 2], edge_index=[2, 12736], y=[64], batch=[1624], ptr=[65])
#
# Step 844:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2091, 2], edge_index=[2, 12736], y=[64], batch=[2091], ptr=[65])
#
# Step 845:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2110, 2], edge_index=[2, 12736], y=[64], batch=[2110], ptr=[65])
#
# Step 846:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1838, 2], edge_index=[2, 12736], y=[64], batch=[1838], ptr=[65])
#
# Step 847:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2071, 2], edge_index=[2, 12736], y=[64], batch=[2071], ptr=[65])
#
# Step 848:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1888, 2], edge_index=[2, 12736], y=[64], batch=[1888], ptr=[65])
#
# Step 849:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1778, 2], edge_index=[2, 12736], y=[64], batch=[1778], ptr=[65])
#
# Step 850:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1884, 2], edge_index=[2, 12736], y=[64], batch=[1884], ptr=[65])
#
# Step 851:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2105, 2], edge_index=[2, 12736], y=[64], batch=[2105], ptr=[65])
#
# Step 852:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1859, 2], edge_index=[2, 12736], y=[64], batch=[1859], ptr=[65])
#
# Step 853:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2195, 2], edge_index=[2, 12736], y=[64], batch=[2195], ptr=[65])
#
# Step 854:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2225, 2], edge_index=[2, 12736], y=[64], batch=[2225], ptr=[65])
#
# Step 855:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2040, 2], edge_index=[2, 12736], y=[64], batch=[2040], ptr=[65])
#
# Step 856:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2078, 2], edge_index=[2, 12736], y=[64], batch=[2078], ptr=[65])
#
# Step 857:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1852, 2], edge_index=[2, 12736], y=[64], batch=[1852], ptr=[65])
#
# Step 858:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1931, 2], edge_index=[2, 12736], y=[64], batch=[1931], ptr=[65])
#
# Step 859:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2014, 2], edge_index=[2, 12736], y=[64], batch=[2014], ptr=[65])
#
# Step 860:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1737, 2], edge_index=[2, 12736], y=[64], batch=[1737], ptr=[65])
#
# Step 861:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1768, 2], edge_index=[2, 12736], y=[64], batch=[1768], ptr=[65])
#
# Step 862:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1878, 2], edge_index=[2, 12736], y=[64], batch=[1878], ptr=[65])
#
# Step 863:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1767, 2], edge_index=[2, 12736], y=[64], batch=[1767], ptr=[65])
#
# Step 864:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1963, 2], edge_index=[2, 12736], y=[64], batch=[1963], ptr=[65])
#
# Step 865:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1751, 2], edge_index=[2, 12736], y=[64], batch=[1751], ptr=[65])
#
# Step 866:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2017, 2], edge_index=[2, 12736], y=[64], batch=[2017], ptr=[65])
#
# Step 867:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1783, 2], edge_index=[2, 12736], y=[64], batch=[1783], ptr=[65])
#
# Step 868:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2044, 2], edge_index=[2, 12736], y=[64], batch=[2044], ptr=[65])
#
# Step 869:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1695, 2], edge_index=[2, 12736], y=[64], batch=[1695], ptr=[65])
#
# Step 870:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1850, 2], edge_index=[2, 12736], y=[64], batch=[1850], ptr=[65])
#
# Step 871:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1745, 2], edge_index=[2, 12736], y=[64], batch=[1745], ptr=[65])
#
# Step 872:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2031, 2], edge_index=[2, 12736], y=[64], batch=[2031], ptr=[65])
#
# Step 873:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1961, 2], edge_index=[2, 12736], y=[64], batch=[1961], ptr=[65])
#
# Step 874:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1918, 2], edge_index=[2, 12736], y=[64], batch=[1918], ptr=[65])
#
# Step 875:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1966, 2], edge_index=[2, 12736], y=[64], batch=[1966], ptr=[65])
#
# Step 876:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2053, 2], edge_index=[2, 12736], y=[64], batch=[2053], ptr=[65])
#
# Step 877:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1569, 2], edge_index=[2, 12736], y=[64], batch=[1569], ptr=[65])
#
# Step 878:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1763, 2], edge_index=[2, 12736], y=[64], batch=[1763], ptr=[65])
#
# Step 879:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1932, 2], edge_index=[2, 12736], y=[64], batch=[1932], ptr=[65])
#
# Step 880:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1755, 2], edge_index=[2, 12736], y=[64], batch=[1755], ptr=[65])
#
# Step 881:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1845, 2], edge_index=[2, 12736], y=[64], batch=[1845], ptr=[65])
#
# Step 882:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2378, 2], edge_index=[2, 12736], y=[64], batch=[2378], ptr=[65])
#
# Step 883:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1721, 2], edge_index=[2, 12736], y=[64], batch=[1721], ptr=[65])
#
# Step 884:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2084, 2], edge_index=[2, 12736], y=[64], batch=[2084], ptr=[65])
#
# Step 885:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1976, 2], edge_index=[2, 12736], y=[64], batch=[1976], ptr=[65])
#
# Step 886:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2389, 2], edge_index=[2, 12736], y=[64], batch=[2389], ptr=[65])
#
# Step 887:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2134, 2], edge_index=[2, 12736], y=[64], batch=[2134], ptr=[65])
#
# Step 888:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1886, 2], edge_index=[2, 12736], y=[64], batch=[1886], ptr=[65])
#
# Step 889:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1666, 2], edge_index=[2, 12736], y=[64], batch=[1666], ptr=[65])
#
# Step 890:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2072, 2], edge_index=[2, 12736], y=[64], batch=[2072], ptr=[65])
#
# Step 891:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2029, 2], edge_index=[2, 12736], y=[64], batch=[2029], ptr=[65])
#
# Step 892:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1801, 2], edge_index=[2, 12736], y=[64], batch=[1801], ptr=[65])
#
# Step 893:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1957, 2], edge_index=[2, 12736], y=[64], batch=[1957], ptr=[65])
#
# Step 894:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2058, 2], edge_index=[2, 12736], y=[64], batch=[2058], ptr=[65])
#
# Step 895:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1713, 2], edge_index=[2, 12736], y=[64], batch=[1713], ptr=[65])
#
# Step 896:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1950, 2], edge_index=[2, 12736], y=[64], batch=[1950], ptr=[65])
#
# Step 897:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1955, 2], edge_index=[2, 12736], y=[64], batch=[1955], ptr=[65])
#
# Step 898:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1784, 2], edge_index=[2, 12736], y=[64], batch=[1784], ptr=[65])
#
# Step 899:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1999, 2], edge_index=[2, 12736], y=[64], batch=[1999], ptr=[65])
#
# Step 900:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[2005, 2], edge_index=[2, 12736], y=[64], batch=[2005], ptr=[65])
#
# Step 901:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1869, 2], edge_index=[2, 12736], y=[64], batch=[1869], ptr=[65])
#
# Step 902:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1790, 2], edge_index=[2, 12736], y=[64], batch=[1790], ptr=[65])
#
# Step 903:
# =======
# Number of graphs in the current batch: 19
# DataBatch(x=[556, 2], edge_index=[2, 3781], y=[19], batch=[556], ptr=[20])

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_mean_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GCNConv(2, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, 2)

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        
        return x

model = GCN(hidden_channels=64)
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(2, 64)
#   (conv2): GCNConv(64, 64)
#   (conv3): GCNConv(64, 64)
#   (lin): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
from IPython.display import Javascript
from sklearn.metrics import confusion_matrix
import numpy as np

display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

model = GCN(hidden_channels=64)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()
yTrue = []
yPred = []

def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
         out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
         loss = criterion(out, data.y)  # Compute the loss.
         loss.backward()  # Derive gradients.
         optimizer.step()  # Update parameters based on gradients.
         optimizer.zero_grad()  # Clear gradients.

def test(loader):
     model.eval()

     correct = 0
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch)  
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct += int((pred == data.y).sum())  # Check against ground-truth labels.
     return correct / len(loader.dataset)  # Derive ratio of correct predictions.


kkkk = 11
for epoch in range(1, kkkk):
    train()
    train_acc = test(train_loader)
    
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}')
# Out:
# Epoch: 001, Train Acc: 0.9829
# Epoch: 002, Train Acc: 0.9770
# Epoch: 003, Train Acc: 0.9793
# Epoch: 004, Train Acc: 0.9831
# Epoch: 005, Train Acc: 0.9831
# Epoch: 006, Train Acc: 0.9840
# Epoch: 007, Train Acc: 0.9846
# Epoch: 008, Train Acc: 0.9852
# Epoch: 009, Train Acc: 0.9793
# Epoch: 010, Train Acc: 0.9853

# %%
from sklearn.metrics import confusion_matrix

def conf(yTrue,yPred):
  tp,tn,fp,fn = 0,0,0,0
  for i in range(len(yTrue)):
    if yTrue[i] == yPred[i] and yTrue[i] == 1:
      tn= tn+1

    elif yTrue[i] == yPred[i] and yTrue[i] == 0:
      tp = tp+1
    elif yTrue[i] == 0 and yPred[i] == 1:
      fp=fp+1
    else:
      fn=fn+1
  

  return np.array([[tp,fp],[fn,tn]])
    




def test1(loader):
     model.eval()

     correct = 0
     cf = np.array([[0,0],[0,0]])
     for data in loader:  # Iterate in batches over the training/test dataset.
         out = model(data.x, data.edge_index, data.batch)  
         pred = out.argmax(dim=1)  # Use the class with highest probability.
         correct +=(data.y).sum()  # Check against ground-truth labels.
         c=conf(np.array(data.y),np.array(pred))
         print(c)

         cf = cf+c
     print(correct)
      

     return cf  # Derive ratio of correct predictions.

print('isafhksfh')
cf = test1(test_loader)  


cf = cf.T
print(cf)
print((cf[0][0]+cf[1][1])/(cf[0][0]+cf[0][1]+cf[1][0]+cf[1][1]))
# Out:
# isafhksfh
# [[85  0]
#  [ 3 40]]
# [[83  0]
#  [ 2 43]]
# [[84  0]
#  [ 4 40]]
# [[88  0]
#  [ 1 39]]
# [[98  0]
#  [ 1 29]]
# [[96  0]
#  [ 1 31]]
# [[95  0]
#  [ 1 32]]
# [[88  0]
#  [ 2 38]]
# [[94  0]
#  [ 1 33]]
# [[88  0]
#  [ 2 38]]
# [[88  0]
#  [ 0 40]]
# [[84  1]
#  [ 1 42]]
# [[88  0]
#  [ 3 37]]
# [[92  0]
#  [ 1 35]]
# [[94  0]
#  [ 1 33]]
# [[94  0]
#  [ 4 30]]
# [[90  0]
#  [ 4 34]]
# [[103   0]
#  [  1  24]]
# [[98  0]
#  [ 0 30]]
# [[95  0]
#  [ 0 33]]
# [[100   0]
#  [  0  28]]
# [[87  0]
#  [ 1 40]]
# [[94  0]
#  [ 0 34]]
# [[89  0]
#  [ 3 36]]
# [[87  1]
#  [ 1 39]]
# [[94  1]
#  [ 3 30]]
# [[98  0]
#  [ 2 28]]
# [[95  0]
#  [ 4 29]]
# [[91  0]
#  [ 1 36]]
# [[92  0]
#  [ 3 33]]
# [[89  0]
#  [ 4 35]]
# [[96  0]
#  [ 2 30]]
# [[86  0]
#  [ 2 40]]
# [[84  0]
#  [ 3 41]]
# [[99  0]
#  [ 3 26]]
# [[81  0]
#  [ 2 45]]
# [[93  0]
#  [ 2 33]]
# [[85  0]
#  [ 3 40]]
# [[87  0]
#  [ 0 41]]
# [[91  0]
#  [ 1 36]]
# [[89  0]
#  [ 2 37]]
# [[91  0]
#  [ 2 35]]
# [[94  0]
#  [ 2 32]]
# [[96  0]
#  [ 5 27]]
# [[87  0]
#  [ 1 40]]
# [[92  0]
#  [ 1 35]]
# [[93  0]
#  [ 3 32]]
# [[90  0]
#  [ 0 38]]
# [[97  0]
#  [ 0 31]]
# [[86  1]
#  [ 2 39]]
# [[88  0]
#  [ 0 40]]
# [[92  0]
#  [ 1 35]]
# [[85  0]
#  [ 5 38]]
# [[84  2]
#  [ 1 41]]
# [[89  1]
#  [ 2 36]]
# [[89  0]
#  [ 1 38]]
# [[89  0]
#  [ 2 37]]
# [[90  0]
#  [ 2 36]]
# [[88  0]
#  [ 1 39]]
# [[95  0]
#  [ 2 31]]
# [[92  0]
#  [ 1 35]]
# [[90  0]
#  [ 2 36]]
# [[91  0]
#  [ 0 37]]
# [[102   0]
#  [  0  26]]
# [[88  0]
#  [ 0 40]]
# [[89  0]
#  [ 0 39]]
# [[94  0]
#  [ 0 34]]
# [[84  0]
#  [ 3 41]]
# [[87  0]
#  [ 1 40]]
# [[100   0]
#  [  2  26]]
# [[89  0]
#  [ 1 38]]
# [[100   0]
#  [  4  24]]
# [[99  0]
#  [ 2 27]]
# [[90  0]
#  [ 1 37]]
# [[86  0]
#  [ 0 42]]
# [[94  0]
#  [ 2 32]]
# [[82  0]
#  [ 5 41]]
# [[86  0]
#  [ 3 39]]
# [[94  0]
#  [ 0 34]]
# [[98  0]
#  [ 0 30]]
# [[98  0]
#  [ 2 28]]
# [[84  0]
#  [ 0 44]]
# [[84  1]
#  [ 0 43]]
# [[90  0]
#  [ 3 35]]
# [[93  0]
#  [ 2 33]]
# [[92  0]
#  [ 0 36]]
# [[96  0]
#  [ 1 31]]
# [[91  0]
#  [ 3 34]]
# [[92  0]
#  [ 4 32]]
# [[101   0]
#  [  0  27]]
# [[86  1]
#  [ 3 38]]
# [[93  0]
#  [ 4 31]]
# [[90  1]
#  [ 2 35]]
# [[95  0]
#  [ 2 31]]
# [[95  0]
#  [ 1 32]]
# [[83  1]
#  [ 1 43]]
# [[85  0]
#  [ 5 38]]
# [[83  0]
#  [ 0 45]]
# [[101   0]
#  [  2  25]]
# [[91  0]
#  [ 1 36]]
# [[92  0]
#  [ 0 36]]
# [[81  0]
#  [ 3 44]]
# [[93  0]
#  [ 0 35]]
# [[90  1]
#  [ 6 31]]
# [[85  0]
#  [ 1 42]]
# [[87  0]
#  [ 0 41]]
# [[92  0]
#  [ 1 35]]
# [[89  0]
#  [ 4 35]]
# [[92  0]
#  [ 5 31]]
# [[85  0]
#  [ 1 42]]
# [[94  0]
#  [ 2 32]]
# [[90  0]
#  [ 1 37]]
# [[83  0]
#  [ 2 43]]
# [[94  1]
#  [ 1 32]]
# [[90  1]
#  [ 1 36]]
# [[106   0]
#  [  2  20]]
# [[87  1]
#  [ 2 38]]
# [[89  0]
#  [ 1 38]]
# [[88  2]
#  [ 0 38]]
# [[101   0]
#  [  3  24]]
# [[95  0]
#  [ 5 28]]
# [[94  0]
#  [ 4 30]]
# [[94  0]
#  [ 0 34]]
# [[84  0]
#  [ 1 43]]
# [[92  0]
#  [ 1 35]]
# [[95  0]
#  [ 1 32]]
# [[85  0]
#  [ 1 42]]
# [[84  0]
#  [ 3 41]]
# [[89  0]
#  [ 2 37]]
# [[86  2]
#  [ 3 37]]
# [[93  1]
#  [ 3 31]]
# [[90  0]
#  [ 1 37]]
# [[92  0]
#  [ 3 33]]
# [[96  0]
#  [ 2 30]]
# [[94  0]
#  [ 3 31]]
# [[92  0]
#  [ 2 34]]
# [[89  0]
#  [ 1 38]]
# [[82  0]
#  [ 1 45]]
# [[92  0]
#  [ 2 34]]
# [[97  0]
#  [ 1 30]]
# [[88  0]
#  [ 1 39]]
# [[96  0]
#  [ 2 30]]
# [[100   0]
#  [  1  27]]
# [[95  0]
#  [ 2 31]]
# [[99  0]
#  [ 0 29]]
# [[96  0]
#  [ 1 31]]
# [[97  0]
#  [ 1 30]]
# [[96  0]
#  [ 2 30]]
# [[90  0]
#  [ 2 36]]
# [[87  0]
#  [ 1 40]]
# [[100   0]
#  [  0  28]]
# [[92  0]
#  [ 2 34]]
# [[70  0]
#  [ 0 58]]
# [[87  0]
#  [ 3 38]]
# [[93  0]
#  [ 2 33]]
# [[87  0]
#  [ 1 40]]
# [[91  0]
#  [ 2 35]]
# [[92  0]
#  [ 3 33]]
# [[83  1]
#  [ 1 43]]
# [[97  0]
#  [ 1 30]]
# [[91  0]
#  [ 1 36]]
# [[97  0]
#  [ 0 31]]
# [[88  0]
#  [ 3 37]]
# [[92  0]
#  [ 1 35]]
# [[91  0]
#  [ 2 35]]
# [[88  0]
#  [ 1 39]]
# [[98  0]
#  [ 2 28]]
# [[85  0]
#  [ 5 38]]
# [[92  0]
#  [ 1 35]]
# [[88  0]
#  [ 2 38]]
# [[94  0]
#  [ 0 34]]
# [[97  0]
#  [ 3 28]]
# [[100   0]
#  [  0  28]]
# [[86  0]
#  [ 2 40]]
# [[81  0]
#  [ 0 47]]
# [[79  0]
#  [ 2 47]]
# [[89  0]
#  [ 3 36]]
# [[87  0]
#  [ 2 39]]
# [[97  0]
#  [ 1 30]]
# [[105   1]
#  [  1  21]]
# [[85  0]
#  [ 4 39]]
# [[89  0]
#  [ 1 38]]
# [[92  0]
#  [ 2 34]]
# [[90  0]
#  [ 2 36]]
# [[91  0]
#  [ 2 35]]
# [[95  0]
#  [ 1 32]]
# [[79  0]
#  [ 5 44]]
# [[98  0]
#  [ 1 29]]
# [[102   0]
#  [  3  23]]
# [[91  0]
#  [ 2 35]]
# [[84  0]
#  [ 0 44]]
# [[95  0]
#  [ 1 32]]
# [[85  0]
#  [ 3 40]]
# [[34  0]
#  [ 0 12]]
# tensor(7129)
# [[17599   334]
#  [   22  6795]]
# 0.9856161616161616

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np



cm = cf


cm_matrix = pd.DataFrame(data=cm, columns=["Attack free","Mixed attacks"], 
                                 index=["Attack free","Mixed attacks"])
sns.set(font_scale=2.0)
sns.heatmap(cm_matrix, annot=True, fmt= 'g', cmap='YlGnBu')
plt.rcParams['font.size'] = 3
plt.rcParams['figure.figsize'] = (3, 3)  
# plt.title("Confusion Matrix for All attack")
plt.xlabel("Actual label")
plt.ylabel("Predicted label")
plt.yticks(rotation = 45)
plt.xticks(rotation = 45, ha = 'right')
 
plt.savefig('confusion_mixed.pdf', bbox_inches = "tight")
# plt.savefig('confusion_mixed.svg', bbox_inches = "tight")
# plt.savefig('confusion_mixed.png', bbox_inches = "tight")
# Out:
# 12829
# 2749
# 2749
# torch.Size([18328, 11])
# Epoch: 0001 loss_train: 7.6337 acc_train: 0.4098 loss_val: 6.3732 acc_val: 0.0000 time: 3.1980s
# Epoch: 0002 loss_train: 6.1403 acc_train: 0.4537 loss_val: 3.6720 acc_val: 0.0004 time: 3.2029s
# Epoch: 0003 loss_train: 5.2571 acc_train: 0.4728 loss_val: 1.6822 acc_val: 0.0266 time: 3.2154s
# Epoch: 0004 loss_train: 4.3784 acc_train: 0.4959 loss_val: 0.7081 acc_val: 0.6257 time: 3.2163s
# Epoch: 0005 loss_train: 3.7808 acc_train: 0.5108 loss_val: 0.3234 acc_val: 0.9251 time: 3.2138s
# Epoch: 0006 loss_train: 3.1041 acc_train: 0.5385 loss_val: 0.1696 acc_val: 0.9825 time: 3.2134s
# Epoch: 0007 loss_train: 2.4855 acc_train: 0.5926 loss_val: 0.0965 acc_val: 0.9956 time: 3.2264s
# Epoch: 0008 loss_train: 1.9026 acc_train: 0.6389 loss_val: 0.0577 acc_val: 0.9996 time: 3.2210s
# Epoch: 0009 loss_train: 1.5366 acc_train: 0.6977 loss_val: 0.0386 acc_val: 1.0000 time: 3.2166s
# Epoch: 0010 loss_train: 1.2613 acc_train: 0.7397 loss_val: 0.0468 acc_val: 1.0000 time: 3.2610s
# Epoch: 0011 loss_train: 1.0972 acc_train: 0.7656 loss_val: 0.0734 acc_val: 1.0000 time: 3.2887s
# Epoch: 0012 loss_train: 0.9655 acc_train: 0.7664 loss_val: 0.1126 acc_val: 1.0000 time: 3.2086s
# Epoch: 0013 loss_train: 0.8745 acc_train: 0.7872 loss_val: 0.1574 acc_val: 1.0000 time: 3.2382s
# Epoch: 0014 loss_train: 0.8406 acc_train: 0.7870 loss_val: 0.1946 acc_val: 1.0000 time: 3.2419s
# Epoch: 0015 loss_train: 0.7501 acc_train: 0.7786 loss_val: 0.2196 acc_val: 1.0000 time: 3.2437s
# Epoch: 0016 loss_train: 0.7015 acc_train: 0.7782 loss_val: 0.2370 acc_val: 1.0000 time: 3.2407s
# Epoch: 0017 loss_train: 0.6254 acc_train: 0.7722 loss_val: 0.2513 acc_val: 1.0000 time: 3.2323s
# Epoch: 0018 loss_train: 0.5726 acc_train: 0.7650 loss_val: 0.2661 acc_val: 1.0000 time: 3.2024s
# Epoch: 0019 loss_train: 0.5421 acc_train: 0.7552 loss_val: 0.2857 acc_val: 1.0000 time: 3.2051s
# Epoch: 0020 loss_train: 0.5835 acc_train: 0.7355 loss_val: 0.3146 acc_val: 1.0000 time: 3.2045s
# Epoch: 0021 loss_train: 0.5221 acc_train: 0.7831 loss_val: 0.3609 acc_val: 1.0000 time: 3.2259s
# Epoch: 0022 loss_train: 0.5209 acc_train: 0.7815 loss_val: 0.4118 acc_val: 1.0000 time: 3.2017s
# Epoch: 0023 loss_train: 0.5152 acc_train: 0.7998 loss_val: 0.4544 acc_val: 1.0000 time: 3.2102s
# Epoch: 0024 loss_train: 0.5142 acc_train: 0.8303 loss_val: 0.4830 acc_val: 1.0000 time: 3.2234s
# Epoch: 0025 loss_train: 0.5180 acc_train: 0.7825 loss_val: 0.4871 acc_val: 1.0000 time: 3.2256s
# Epoch: 0026 loss_train: 0.5234 acc_train: 0.7814 loss_val: 0.4586 acc_val: 1.0000 time: 3.2245s
# Epoch: 0027 loss_train: 0.5149 acc_train: 0.7863 loss_val: 0.4151 acc_val: 1.0000 time: 3.2124s
# Epoch: 0028 loss_train: 0.5125 acc_train: 0.8380 loss_val: 0.3656 acc_val: 1.0000 time: 3.2253s
# Epoch: 0029 loss_train: 0.4928 acc_train: 0.8400 loss_val: 0.3060 acc_val: 1.0000 time: 3.2112s
# Epoch: 0030 loss_train: 0.4764 acc_train: 0.8383 loss_val: 0.2640 acc_val: 1.0000 time: 3.1861s
# Epoch: 0031 loss_train: 0.4664 acc_train: 0.8408 loss_val: 0.2371 acc_val: 1.0000 time: 3.2087s
# Epoch: 0032 loss_train: 0.4483 acc_train: 0.8537 loss_val: 0.2218 acc_val: 1.0000 time: 3.1896s
# Epoch: 0033 loss_train: 0.4334 acc_train: 0.8630 loss_val: 0.2106 acc_val: 1.0000 time: 3.1860s
# Epoch: 0034 loss_train: 0.4230 acc_train: 0.8624 loss_val: 0.2015 acc_val: 1.0000 time: 3.2028s
# Epoch: 0035 loss_train: 0.4184 acc_train: 0.8637 loss_val: 0.1904 acc_val: 1.0000 time: 3.2433s
# Epoch: 0036 loss_train: 0.4104 acc_train: 0.8633 loss_val: 0.1768 acc_val: 1.0000 time: 3.2030s
# Epoch: 0037 loss_train: 0.4155 acc_train: 0.8552 loss_val: 0.1617 acc_val: 1.0000 time: 3.1930s
# Epoch: 0038 loss_train: 0.4140 acc_train: 0.8518 loss_val: 0.1463 acc_val: 1.0000 time: 3.2109s
# Epoch: 0039 loss_train: 0.4114 acc_train: 0.8505 loss_val: 0.1317 acc_val: 1.0000 time: 3.2056s
# Epoch: 0040 loss_train: 0.4157 acc_train: 0.8499 loss_val: 0.1198 acc_val: 1.0000 time: 3.1971s
# Epoch: 0041 loss_train: 0.4106 acc_train: 0.8556 loss_val: 0.1105 acc_val: 1.0000 time: 3.2042s
# Epoch: 0042 loss_train: 0.4065 acc_train: 0.8589 loss_val: 0.1048 acc_val: 1.0000 time: 3.1843s
# Epoch: 0043 loss_train: 0.4014 acc_train: 0.8616 loss_val: 0.1023 acc_val: 1.0000 time: 3.1936s
# Epoch: 0044 loss_train: 0.3982 acc_train: 0.8637 loss_val: 0.1028 acc_val: 1.0000 time: 3.2277s
# Epoch: 0045 loss_train: 0.4007 acc_train: 0.8602 loss_val: 0.1053 acc_val: 1.0000 time: 3.2102s
# Epoch: 0046 loss_train: 0.4084 acc_train: 0.8596 loss_val: 0.1097 acc_val: 1.0000 time: 3.2258s
# Epoch: 0047 loss_train: 0.3986 acc_train: 0.8641 loss_val: 0.1150 acc_val: 1.0000 time: 3.2149s
# Epoch: 0048 loss_train: 0.4045 acc_train: 0.8595 loss_val: 0.1198 acc_val: 1.0000 time: 3.2103s
# Epoch: 0049 loss_train: 0.3966 acc_train: 0.8604 loss_val: 0.1239 acc_val: 1.0000 time: 3.2134s
# Epoch: 0050 loss_train: 0.3855 acc_train: 0.8630 loss_val: 0.1244 acc_val: 1.0000 time: 3.2146s
# Epoch: 0051 loss_train: 0.3878 acc_train: 0.8616 loss_val: 0.1217 acc_val: 1.0000 time: 3.2268s
# Epoch: 0052 loss_train: 0.3924 acc_train: 0.8583 loss_val: 0.1181 acc_val: 1.0000 time: 3.2159s
# Epoch: 0053 loss_train: 0.3960 acc_train: 0.8570 loss_val: 0.1150 acc_val: 1.0000 time: 3.2110s
# Epoch: 0054 loss_train: 0.3856 acc_train: 0.8606 loss_val: 0.1137 acc_val: 1.0000 time: 3.2416s
# Epoch: 0055 loss_train: 0.3872 acc_train: 0.8628 loss_val: 0.1145 acc_val: 1.0000 time: 3.2236s
# Epoch: 0056 loss_train: 0.3844 acc_train: 0.8619 loss_val: 0.1169 acc_val: 1.0000 time: 3.2058s
# Epoch: 0057 loss_train: 0.3864 acc_train: 0.8633 loss_val: 0.1214 acc_val: 1.0000 time: 3.1880s
# Epoch: 0058 loss_train: 0.3871 acc_train: 0.8630 loss_val: 0.1274 acc_val: 1.0000 time: 3.1767s
# Epoch: 0059 loss_train: 0.3849 acc_train: 0.8635 loss_val: 0.1304 acc_val: 1.0000 time: 3.1653s
# Epoch: 0060 loss_train: 0.3878 acc_train: 0.8635 loss_val: 0.1318 acc_val: 1.0000 time: 3.1839s
# Epoch: 0061 loss_train: 0.3837 acc_train: 0.8636 loss_val: 0.1298 acc_val: 1.0000 time: 3.1740s
# Epoch: 0062 loss_train: 0.3842 acc_train: 0.8630 loss_val: 0.1236 acc_val: 1.0000 time: 3.2018s
# Epoch: 0063 loss_train: 0.3760 acc_train: 0.8643 loss_val: 0.1148 acc_val: 1.0000 time: 3.2399s
# Epoch: 0064 loss_train: 0.3836 acc_train: 0.8632 loss_val: 0.1089 acc_val: 1.0000 time: 3.2779s
# Epoch: 0065 loss_train: 0.3807 acc_train: 0.8608 loss_val: 0.1054 acc_val: 1.0000 time: 3.2439s
# Epoch: 0066 loss_train: 0.3844 acc_train: 0.8618 loss_val: 0.1068 acc_val: 1.0000 time: 3.2122s
# Epoch: 0067 loss_train: 0.3755 acc_train: 0.8655 loss_val: 0.1101 acc_val: 1.0000 time: 3.2138s
# Epoch: 0068 loss_train: 0.3771 acc_train: 0.8666 loss_val: 0.1139 acc_val: 1.0000 time: 3.2340s
# Epoch: 0069 loss_train: 0.3819 acc_train: 0.8657 loss_val: 0.1166 acc_val: 1.0000 time: 3.2114s
# Epoch: 0070 loss_train: 0.3762 acc_train: 0.8659 loss_val: 0.1153 acc_val: 1.0000 time: 3.2154s
# Epoch: 0071 loss_train: 0.3716 acc_train: 0.8675 loss_val: 0.1106 acc_val: 1.0000 time: 3.1969s
# Epoch: 0072 loss_train: 0.3809 acc_train: 0.8633 loss_val: 0.1046 acc_val: 1.0000 time: 3.2137s
# Epoch: 0073 loss_train: 0.3797 acc_train: 0.8663 loss_val: 0.0989 acc_val: 1.0000 time: 3.2144s
# Epoch: 0074 loss_train: 0.3793 acc_train: 0.8635 loss_val: 0.0951 acc_val: 1.0000 time: 3.2193s
# Epoch: 0075 loss_train: 0.3746 acc_train: 0.8641 loss_val: 0.0951 acc_val: 1.0000 time: 3.2200s
# Epoch: 0076 loss_train: 0.3779 acc_train: 0.8645 loss_val: 0.0967 acc_val: 1.0000 time: 3.2207s
# Epoch: 0077 loss_train: 0.3793 acc_train: 0.8651 loss_val: 0.0988 acc_val: 1.0000 time: 3.8769s
# Epoch: 0078 loss_train: 0.3719 acc_train: 0.8666 loss_val: 0.1011 acc_val: 1.0000 time: 3.8890s
# Epoch: 0079 loss_train: 0.3782 acc_train: 0.8646 loss_val: 0.1026 acc_val: 1.0000 time: 3.1795s
# Epoch: 0080 loss_train: 0.3778 acc_train: 0.8639 loss_val: 0.1019 acc_val: 1.0000 time: 3.1929s
# Epoch: 0081 loss_train: 0.3738 acc_train: 0.8639 loss_val: 0.0992 acc_val: 1.0000 time: 3.1960s
# Epoch: 0082 loss_train: 0.3772 acc_train: 0.8637 loss_val: 0.0974 acc_val: 1.0000 time: 3.1857s
# Epoch: 0083 loss_train: 0.3759 acc_train: 0.8613 loss_val: 0.0970 acc_val: 1.0000 time: 3.4921s
# Epoch: 0084 loss_train: 0.3718 acc_train: 0.8651 loss_val: 0.0967 acc_val: 1.0000 time: 3.4219s
# Epoch: 0085 loss_train: 0.3702 acc_train: 0.8657 loss_val: 0.0972 acc_val: 1.0000 time: 3.7369s
# Epoch: 0086 loss_train: 0.3728 acc_train: 0.8677 loss_val: 0.0974 acc_val: 1.0000 time: 3.3185s
# Epoch: 0087 loss_train: 0.3733 acc_train: 0.8649 loss_val: 0.0993 acc_val: 1.0000 time: 3.5114s
# Epoch: 0088 loss_train: 0.3735 acc_train: 0.8651 loss_val: 0.1013 acc_val: 1.0000 time: 3.2337s
# Epoch: 0089 loss_train: 0.3774 acc_train: 0.8674 loss_val: 0.1039 acc_val: 1.0000 time: 3.2657s
# Epoch: 0090 loss_train: 0.3766 acc_train: 0.8643 loss_val: 0.1034 acc_val: 1.0000 time: 3.3368s
# Epoch: 0091 loss_train: 0.3680 acc_train: 0.8697 loss_val: 0.1020 acc_val: 1.0000 time: 3.2910s
# Epoch: 0092 loss_train: 0.3759 acc_train: 0.8648 loss_val: 0.1002 acc_val: 1.0000 time: 3.2607s
# Epoch: 0093 loss_train: 0.3711 acc_train: 0.8685 loss_val: 0.0997 acc_val: 1.0000 time: 3.2650s
# Epoch: 0094 loss_train: 0.3742 acc_train: 0.8661 loss_val: 0.1003 acc_val: 1.0000 time: 3.2202s
# Epoch: 0095 loss_train: 0.3746 acc_train: 0.8641 loss_val: 0.1015 acc_val: 1.0000 time: 3.2590s
# Epoch: 0096 loss_train: 0.3718 acc_train: 0.8659 loss_val: 0.1018 acc_val: 1.0000 time: 3.2375s
# Epoch: 0097 loss_train: 0.3696 acc_train: 0.8655 loss_val: 0.1022 acc_val: 1.0000 time: 3.2272s
# Epoch: 0098 loss_train: 0.3751 acc_train: 0.8644 loss_val: 0.1033 acc_val: 1.0000 time: 3.2187s
# Epoch: 0099 loss_train: 0.3698 acc_train: 0.8691 loss_val: 0.1034 acc_val: 1.0000 time: 3.2358s
# Epoch: 0100 loss_train: 0.3795 acc_train: 0.8647 loss_val: 0.1025 acc_val: 1.0000 time: 3.2179s
# Epoch: 0101 loss_train: 0.3706 acc_train: 0.8669 loss_val: 0.1001 acc_val: 1.0000 time: 3.2531s
# Epoch: 0102 loss_train: 0.3670 acc_train: 0.8648 loss_val: 0.0975 acc_val: 1.0000 time: 3.2576s
# Epoch: 0103 loss_train: 0.3706 acc_train: 0.8650 loss_val: 0.0971 acc_val: 1.0000 time: 3.2381s
# Epoch: 0104 loss_train: 0.3695 acc_train: 0.8625 loss_val: 0.0968 acc_val: 1.0000 time: 3.2002s
# Epoch: 0105 loss_train: 0.3675 acc_train: 0.8676 loss_val: 0.0977 acc_val: 1.0000 time: 3.1775s
# Epoch: 0106 loss_train: 0.3679 acc_train: 0.8659 loss_val: 0.0987 acc_val: 1.0000 time: 3.1678s
# Epoch: 0107 loss_train: 0.3732 acc_train: 0.8668 loss_val: 0.0996 acc_val: 1.0000 time: 3.2334s
# Epoch: 0108 loss_train: 0.3745 acc_train: 0.8650 loss_val: 0.0991 acc_val: 1.0000 time: 3.2220s
# Epoch: 0109 loss_train: 0.3701 acc_train: 0.8686 loss_val: 0.0985 acc_val: 1.0000 time: 3.2400s
# Epoch: 0110 loss_train: 0.3739 acc_train: 0.8649 loss_val: 0.0989 acc_val: 1.0000 time: 3.2242s
# Epoch: 0111 loss_train: 0.3710 acc_train: 0.8652 loss_val: 0.0995 acc_val: 1.0000 time: 3.2312s
# Epoch: 0112 loss_train: 0.3714 acc_train: 0.8651 loss_val: 0.0997 acc_val: 1.0000 time: 3.2138s
# Epoch: 0113 loss_train: 0.3686 acc_train: 0.8676 loss_val: 0.1003 acc_val: 1.0000 time: 3.2530s
# Epoch: 0114 loss_train: 0.3734 acc_train: 0.8640 loss_val: 0.0994 acc_val: 1.0000 time: 3.2100s
# Epoch: 0115 loss_train: 0.3704 acc_train: 0.8669 loss_val: 0.0998 acc_val: 1.0000 time: 3.2092s
# Epoch: 0116 loss_train: 0.3723 acc_train: 0.8662 loss_val: 0.0994 acc_val: 1.0000 time: 3.1973s
# Epoch: 0117 loss_train: 0.3700 acc_train: 0.8656 loss_val: 0.0995 acc_val: 1.0000 time: 3.2344s
# Epoch: 0118 loss_train: 0.3722 acc_train: 0.8659 loss_val: 0.1005 acc_val: 1.0000 time: 3.2229s
# Epoch: 0119 loss_train: 0.3644 acc_train: 0.8692 loss_val: 0.1010 acc_val: 1.0000 time: 3.2357s
# Epoch: 0120 loss_train: 0.3716 acc_train: 0.8669 loss_val: 0.1014 acc_val: 1.0000 time: 3.2304s
# Epoch: 0121 loss_train: 0.3681 acc_train: 0.8687 loss_val: 0.1019 acc_val: 1.0000 time: 3.2611s
# Epoch: 0122 loss_train: 0.3687 acc_train: 0.8661 loss_val: 0.1011 acc_val: 1.0000 time: 3.2190s
# Epoch: 0123 loss_train: 0.3695 acc_train: 0.8693 loss_val: 0.1005 acc_val: 1.0000 time: 3.2386s
# Epoch: 0124 loss_train: 0.3706 acc_train: 0.8652 loss_val: 0.0988 acc_val: 1.0000 time: 3.5511s
# Epoch: 0125 loss_train: 0.3701 acc_train: 0.8660 loss_val: 0.0980 acc_val: 1.0000 time: 3.2309s
# Epoch: 0126 loss_train: 0.3696 acc_train: 0.8654 loss_val: 0.0981 acc_val: 1.0000 time: 3.2247s
# Epoch: 0127 loss_train: 0.3650 acc_train: 0.8680 loss_val: 0.0999 acc_val: 1.0000 time: 3.2440s
# Epoch: 0128 loss_train: 0.3693 acc_train: 0.8627 loss_val: 0.1008 acc_val: 1.0000 time: 3.2084s
# Epoch: 0129 loss_train: 0.3655 acc_train: 0.8687 loss_val: 0.0995 acc_val: 1.0000 time: 3.1914s
# Epoch: 0130 loss_train: 0.3720 acc_train: 0.8641 loss_val: 0.0993 acc_val: 1.0000 time: 3.2051s
# Epoch: 0131 loss_train: 0.3691 acc_train: 0.8643 loss_val: 0.0969 acc_val: 1.0000 time: 3.2087s
# Epoch: 0132 loss_train: 0.3696 acc_train: 0.8697 loss_val: 0.0964 acc_val: 1.0000 time: 3.2195s
# Epoch: 0133 loss_train: 0.3659 acc_train: 0.8697 loss_val: 0.0968 acc_val: 1.0000 time: 3.2363s
# Epoch: 0134 loss_train: 0.3692 acc_train: 0.8680 loss_val: 0.0981 acc_val: 1.0000 time: 3.1977s
# Epoch: 0135 loss_train: 0.3717 acc_train: 0.8694 loss_val: 0.0998 acc_val: 1.0000 time: 3.2166s
# Epoch: 0136 loss_train: 0.3710 acc_train: 0.8687 loss_val: 0.1022 acc_val: 1.0000 time: 3.2137s
# Epoch: 0137 loss_train: 0.3728 acc_train: 0.8659 loss_val: 0.1037 acc_val: 1.0000 time: 3.2232s
# Epoch: 0138 loss_train: 0.3725 acc_train: 0.8664 loss_val: 0.1038 acc_val: 1.0000 time: 3.2208s
# Epoch: 0139 loss_train: 0.3683 acc_train: 0.8703 loss_val: 0.1020 acc_val: 1.0000 time: 3.2061s
# Epoch: 0140 loss_train: 0.3655 acc_train: 0.8662 loss_val: 0.1004 acc_val: 1.0000 time: 3.1903s
# Epoch: 0141 loss_train: 0.3732 acc_train: 0.8652 loss_val: 0.1000 acc_val: 1.0000 time: 3.1749s
# Epoch: 0142 loss_train: 0.3686 acc_train: 0.8668 loss_val: 0.0994 acc_val: 1.0000 time: 3.1867s
# Epoch: 0143 loss_train: 0.3711 acc_train: 0.8632 loss_val: 0.0994 acc_val: 1.0000 time: 3.2098s
# Epoch: 0144 loss_train: 0.3653 acc_train: 0.8662 loss_val: 0.0986 acc_val: 1.0000 time: 3.2235s
# Epoch: 0145 loss_train: 0.3687 acc_train: 0.8673 loss_val: 0.0988 acc_val: 1.0000 time: 3.2359s
# Epoch: 0146 loss_train: 0.3635 acc_train: 0.8697 loss_val: 0.0971 acc_val: 1.0000 time: 3.2127s
# Epoch: 0147 loss_train: 0.3738 acc_train: 0.8654 loss_val: 0.0951 acc_val: 1.0000 time: 3.1674s
# Epoch: 0148 loss_train: 0.3659 acc_train: 0.8651 loss_val: 0.0931 acc_val: 1.0000 time: 3.1630s
# Epoch: 0149 loss_train: 0.3639 acc_train: 0.8685 loss_val: 0.0920 acc_val: 1.0000 time: 3.1895s
# Epoch: 0150 loss_train: 0.3675 acc_train: 0.8653 loss_val: 0.0910 acc_val: 1.0000 time: 3.1742s
# Epoch: 0151 loss_train: 0.3663 acc_train: 0.8712 loss_val: 0.0912 acc_val: 1.0000 time: 3.1990s
# Epoch: 0152 loss_train: 0.3676 acc_train: 0.8669 loss_val: 0.0925 acc_val: 1.0000 time: 3.1880s
# Epoch: 0153 loss_train: 0.3647 acc_train: 0.8648 loss_val: 0.0941 acc_val: 1.0000 time: 3.1918s
# Epoch: 0154 loss_train: 0.3613 acc_train: 0.8701 loss_val: 0.0942 acc_val: 1.0000 time: 3.1655s
# Epoch: 0155 loss_train: 0.3672 acc_train: 0.8666 loss_val: 0.0936 acc_val: 1.0000 time: 3.1547s
# Epoch: 0156 loss_train: 0.3684 acc_train: 0.8676 loss_val: 0.0956 acc_val: 1.0000 time: 3.1510s
# Epoch: 0157 loss_train: 0.3687 acc_train: 0.8669 loss_val: 0.0984 acc_val: 1.0000 time: 3.1646s
# Epoch: 0158 loss_train: 0.3627 acc_train: 0.8683 loss_val: 0.0994 acc_val: 1.0000 time: 3.1818s
# Epoch: 0159 loss_train: 0.3662 acc_train: 0.8679 loss_val: 0.0994 acc_val: 1.0000 time: 3.1598s
# Epoch: 0160 loss_train: 0.3627 acc_train: 0.8698 loss_val: 0.0997 acc_val: 1.0000 time: 3.1691s
# Epoch: 0161 loss_train: 0.3728 acc_train: 0.8665 loss_val: 0.0982 acc_val: 1.0000 time: 3.2076s
# Epoch: 0162 loss_train: 0.3673 acc_train: 0.8694 loss_val: 0.0980 acc_val: 1.0000 time: 3.1911s
# Epoch: 0163 loss_train: 0.3620 acc_train: 0.8704 loss_val: 0.0972 acc_val: 1.0000 time: 3.1588s
# Epoch: 0164 loss_train: 0.3709 acc_train: 0.8670 loss_val: 0.0963 acc_val: 1.0000 time: 3.1738s
# Epoch: 0165 loss_train: 0.3705 acc_train: 0.8676 loss_val: 0.0955 acc_val: 1.0000 time: 3.1866s
# Epoch: 0166 loss_train: 0.3644 acc_train: 0.8681 loss_val: 0.0937 acc_val: 1.0000 time: 3.1494s
# Epoch: 0167 loss_train: 0.3647 acc_train: 0.8725 loss_val: 0.0938 acc_val: 1.0000 time: 3.1423s
# Epoch: 0168 loss_train: 0.3630 acc_train: 0.8700 loss_val: 0.0934 acc_val: 1.0000 time: 3.1435s
# Epoch: 0169 loss_train: 0.3693 acc_train: 0.8687 loss_val: 0.0958 acc_val: 1.0000 time: 3.1504s
# Epoch: 0170 loss_train: 0.3646 acc_train: 0.8686 loss_val: 0.0971 acc_val: 1.0000 time: 3.1431s
# Epoch: 0171 loss_train: 0.3652 acc_train: 0.8661 loss_val: 0.0962 acc_val: 1.0000 time: 3.1530s
# Epoch: 0172 loss_train: 0.3729 acc_train: 0.8660 loss_val: 0.0954 acc_val: 1.0000 time: 3.1567s
# Epoch: 0173 loss_train: 0.3629 acc_train: 0.8707 loss_val: 0.0940 acc_val: 1.0000 time: 3.1383s
# Epoch: 0174 loss_train: 0.3648 acc_train: 0.8689 loss_val: 0.0930 acc_val: 1.0000 time: 3.1453s
# Epoch: 0175 loss_train: 0.3675 acc_train: 0.8634 loss_val: 0.0911 acc_val: 1.0000 time: 3.1253s
# Epoch: 0176 loss_train: 0.3637 acc_train: 0.8700 loss_val: 0.0908 acc_val: 1.0000 time: 3.1280s
# Epoch: 0177 loss_train: 0.3612 acc_train: 0.8721 loss_val: 0.0915 acc_val: 1.0000 time: 3.1580s
# Epoch: 0178 loss_train: 0.3666 acc_train: 0.8666 loss_val: 0.0953 acc_val: 1.0000 time: 3.1350s
# Epoch: 0179 loss_train: 0.3643 acc_train: 0.8701 loss_val: 0.0974 acc_val: 1.0000 time: 3.1310s
# Epoch: 0180 loss_train: 0.3659 acc_train: 0.8686 loss_val: 0.0963 acc_val: 1.0000 time: 3.1490s
# Epoch: 0181 loss_train: 0.3745 acc_train: 0.8655 loss_val: 0.0942 acc_val: 1.0000 time: 3.1517s
# Epoch: 0182 loss_train: 0.3687 acc_train: 0.8672 loss_val: 0.0927 acc_val: 1.0000 time: 3.1555s
# Epoch: 0183 loss_train: 0.3637 acc_train: 0.8666 loss_val: 0.0916 acc_val: 1.0000 time: 3.1468s
# Epoch: 0184 loss_train: 0.3642 acc_train: 0.8686 loss_val: 0.0924 acc_val: 1.0000 time: 3.1617s
# Epoch: 0185 loss_train: 0.3664 acc_train: 0.8690 loss_val: 0.0944 acc_val: 1.0000 time: 3.1549s
# Epoch: 0186 loss_train: 0.3659 acc_train: 0.8692 loss_val: 0.0967 acc_val: 1.0000 time: 3.1184s
# Epoch: 0187 loss_train: 0.3641 acc_train: 0.8688 loss_val: 0.0975 acc_val: 1.0000 time: 3.1303s
# Epoch: 0188 loss_train: 0.3693 acc_train: 0.8634 loss_val: 0.0953 acc_val: 1.0000 time: 3.1274s
# Epoch: 0189 loss_train: 0.3650 acc_train: 0.8662 loss_val: 0.0923 acc_val: 1.0000 time: 3.1411s
# Epoch: 0190 loss_train: 0.3689 acc_train: 0.8673 loss_val: 0.0920 acc_val: 1.0000 time: 3.1227s
# Epoch: 0191 loss_train: 0.3671 acc_train: 0.8668 loss_val: 0.0935 acc_val: 1.0000 time: 3.1400s
# Epoch: 0192 loss_train: 0.3646 acc_train: 0.8668 loss_val: 0.0949 acc_val: 1.0000 time: 3.1692s
# Epoch: 0193 loss_train: 0.3623 acc_train: 0.8661 loss_val: 0.0935 acc_val: 1.0000 time: 3.1431s
# Epoch: 0194 loss_train: 0.3647 acc_train: 0.8664 loss_val: 0.0914 acc_val: 1.0000 time: 3.1305s
# Epoch: 0195 loss_train: 0.3667 acc_train: 0.8686 loss_val: 0.0931 acc_val: 1.0000 time: 3.1427s
# Epoch: 0196 loss_train: 0.3702 acc_train: 0.8681 loss_val: 0.0951 acc_val: 1.0000 time: 3.1281s
# Epoch: 0197 loss_train: 0.3619 acc_train: 0.8659 loss_val: 0.0960 acc_val: 1.0000 time: 3.1478s
# Epoch: 0198 loss_train: 0.3643 acc_train: 0.8682 loss_val: 0.0953 acc_val: 1.0000 time: 3.1464s
# Epoch: 0199 loss_train: 0.3693 acc_train: 0.8700 loss_val: 0.0951 acc_val: 1.0000 time: 3.1338s
# Epoch: 0200 loss_train: 0.3618 acc_train: 0.8685 loss_val: 0.0931 acc_val: 1.0000 time: 3.1267s
# Optimization Finished!
# Total time elapsed: 643.4834s
# [[2516   30]
#  [  25  178]]
# Test set results: loss= 0.1356 accuracy= 0.9800

# %%
# cm = [[1612 ,  10],
#  [   5  ,793]]


tp = cm[0][0]
tn = cm[1][1]
fp = cm[0][1]
fn = cm[1][0]

re = tp/(tp+fn)
pr = tp/(tp+fp)
f1 = 2*pr*re/(pr+re)
fpr = fp / (fp+tn)
print("pr.........."+str(pr))
print("re----"+str(re))

print("f1===="+str(f1))
print("fpr====="+ str(fpr))
print((tp+tn)/(tp+tn+fp+fn))
# Out:
# pr..........0.98989898989899
# re----0.9932432432432432
# f1====0.9915682967959528
# fpr=====0.009708737864077669
# 0.9917355371900827

# %%
71002
170939
0.991287131986724
[[170760   1929]
 [   179  69073]]
 5

35791
85180
0.9906010531449686
[[84065    22]
 [ 1115 35769]]
 10


3659
8438
0.9962800694387038
[[8424   31]
 [  14 3628]]
100


1832
4217
0.993387336749876
[[4197   20]
 [  20 1812]]

803
1617
0.993801652892562
[[1612   10]
 [   5  793]]
 500



 464
746
0.9917355371900827
[[743   7]
 [  3 457]]
 1000



 309
296
0.9917355371900827
[[294   3]
 [  2 306]]
 2k

 175
67
1.0
[[ 67   0]
 [  0 175]]
 5k


 88
33
1.0
[[33  0]
 [ 0 88]]
 10k

# %%
cm =[ [[170760 ,  1929],
 [179 , 69073]],

 [[84065   , 22],
 [ 1115, 35769]],

[[8424 ,  31],
 [  14, 3628]],

 [[4197 ,  20],
 [  20 ,1812]],

 [[1612  , 10],
 [   5  ,793]],

[[743 ,  7],
 [  3 ,457]],


 [[ 67 ,  0],
 [  0 ,175]],

 [[33,  0],
 [ 0, 88]]
]

for i in range(len(cm)):

  tp = cm[i][0][0]
  tn = cm[i][1][1]
  fp = cm[i][0][1]
  fn = cm[i][1][0]

  re = tp/(tp+fn)
  pr = tp/(tp+fp)
  f1 = 2*pr*re/(pr+re)
  fpr = fp / (fp+tn)


  mcc = (tp*tn-fp*fn)/((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))**.5

  fdr = fp/(fp+tp)

  # print("pr.........."+str(pr))
  # print("re----"+str(re))

  # print("f1===="+str(f1))
  # print("fpr====="+ str(fpr))
  print("mcccccc--------->" +str(mcc))
  #print("fdr======="+str(fdr))
  # print((tp+tn)/(tp+tn+fp+fn))
# Out:
# mcccccc--------->0.9789880325873227
# mcccccc--------->0.9778659028555149
# mcccccc--------->0.991178167512607
# mcccccc--------->0.9843402613459972
# mcccccc--------->0.9860106010676708
# mcccccc--------->0.9825172905181248
# mcccccc--------->1.0
# mcccccc--------->1.0

# %%
import pandas as pd

square_node_data = pd.DataFrame(
    {"x": [1, 2, 3, 4], "y": [-0.2, 0.3, 0.0, -0.5]}, index=["a", "b", "c", "d"]
)
square_node_data
# Out:
#    x    y
# a  1 -0.2
# b  2  0.3
# c  3  0.0
# d  4 -0.5

# %%
# Out:
#       Nodes  Edges  ...  MaximumPagerank  MininumPagerank
# No.                 ...
# 1        27    112  ...         0.215139         0.011104
# 2        25     75  ...         0.359649         0.018228
# 3        25     88  ...         0.285778         0.015716
# 4        27     97  ...         0.276848         0.014271
# 5        27    137  ...         0.173902         0.013195
# ...     ...    ...  ...              ...              ...
# 1828     26     70  ...         0.077329         0.013768
# 1829     26     73  ...         0.073358         0.011842
# 1830     26     78  ...         0.067820         0.011954
# 1831     26     85  ...         0.071132         0.009662
# 1832     26     76  ...         0.086512         0.008505
#
# [1832 rows x 9 columns]
# StellarGraph: Undirected multigraph
#  Nodes: 1832, Edges: 0
#
#  Node types:
#   default: [1832]
#     Features: float32 vector, length 9
#     Edge types: none
#
#  Edge types:
